# %% [markdown]
# # Language Translation
# In this project, you’re going to take a peek into the realm of neural network machine translation.  You’ll be training a sequence to sequence model on a dataset of English and French sentences that can translate new sentences from English to French.
# ## Get the Data
# Since translating the whole language of English to French will take lots of time to train, we have provided you with a small portion of the English corpus.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import helper
import problem_unittests as tests

source_path = 'data/small_vocab_en'
target_path = 'data/small_vocab_fr'
source_text = helper.load_data(source_path)
target_text = helper.load_data(target_path)

# %% [markdown]
# ## Explore the Data
# Play around with view_sentence_range to view different parts of the data.

# %%
view_sentence_range = (0, 10)

"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import numpy as np

print('Dataset Stats')
print('Roughly the number of unique words: {}'.format(len({word: None for word in source_text.split()})))

sentences = source_text.split('\n')
word_counts = [len(sentence.split()) for sentence in sentences]
print('Number of sentences: {}'.format(len(sentences)))
print('Average number of words in a sentence: {}'.format(np.average(word_counts)))

print()
print('English sentences {} to {}:'.format(*view_sentence_range))
print('\n'.join(source_text.split('\n')[view_sentence_range[0]:view_sentence_range[1]]))
print()
print('French sentences {} to {}:'.format(*view_sentence_range))
print('\n'.join(target_text.split('\n')[view_sentence_range[0]:view_sentence_range[1]]))
# Out:
# Dataset Stats
# Roughly the number of unique words: 227
# Number of sentences: 137861
# Average number of words in a sentence: 13.225277634719028
#
# English sentences 0 to 10:
# new jersey is sometimes quiet during autumn , and it is snowy in april .
# the united states is usually chilly during july , and it is usually freezing in november .
# california is usually quiet during march , and it is usually hot in june .
# the united states is sometimes mild during june , and it is cold in september .
# your least liked fruit is the grape , but my least liked is the apple .
# his favorite fruit is the orange , but my favorite is the grape .
# paris is relaxing during december , but it is usually chilly in july .
# new jersey is busy during spring , and it is never hot in march .
# our least liked fruit is the lemon , but my least liked is the grape .
# the united states is sometimes busy during january , and it is sometimes warm in november .
#
# French sentences 0 to 10:
# new jersey est parfois calme pendant l' automne , et il est neigeux en avril .
# les états-unis est généralement froid en juillet , et il gèle habituellement en novembre .
# california est généralement calme en mars , et il est généralement chaud en juin .
# les états-unis est parfois légère en juin , et il fait froid en septembre .
# votre moins aimé fruit est le raisin , mais mon moins aimé est la pomme .
# son fruit préféré est l'orange , mais mon préféré est le raisin .
# paris est relaxant en décembre , mais il est généralement froid en juillet .
# new jersey est occupé au printemps , et il est jamais chaude en mars .
# notre fruit est moins aimé le citron , mais mon moins aimé est le raisin .
# les états-unis est parfois occupé en janvier , et il est parfois chaud en novembre .

# %% [markdown]
# ## Implement Preprocessing Function
# ### Text to Word Ids
# As you did with other RNNs, you must turn the text into a number so the computer can understand it. In the function `text_to_ids()`, you'll turn `source_text` and `target_text` from words to ids.  However, you need to add the `<EOS>` word id at the end of each sentence from `target_text`.  This will help the neural network predict when the sentence should end.
#
# You can get the `<EOS>` word id by doing:
# ```python
# target_vocab_to_int['<EOS>']
# ```
# You can get other word ids using `source_vocab_to_int` and `target_vocab_to_int`.

# %%
def text_to_ids(source_text, target_text, source_vocab_to_int, target_vocab_to_int):
    """
    Convert source and target text to proper word ids
    :param source_text: String that contains all the source text.
    :param target_text: String that contains all the target text.
    :param source_vocab_to_int: Dictionary to go from the source words to an id
    :param target_vocab_to_int: Dictionary to go from the target words to an id
    :return: A tuple of lists (source_id_text, target_id_text)
    """
    # TODO: Implement Function
    source_id_text = [[source_vocab_to_int[word] for word in sentence.split()] for sentence in source_text.split('\n')]
            
    eos_word = target_vocab_to_int['<EOS>']
    target_id_text = [[target_vocab_to_int[word] for word in sentence.split()] + [eos_word] for sentence in target_text.split('\n')]
              
    #print(target_id_text)
    return (source_id_text, target_id_text)

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_text_to_ids(text_to_ids)
# Out:
# Tests Passed

# %% [markdown]
# ### Preprocess all the data and save it
# Running the code cell below will preprocess all the data and save it to file.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
helper.preprocess_and_save_data(source_path, target_path, text_to_ids)

# %% [markdown]
# # Check Point
# This is your first checkpoint. If you ever decide to come back to this notebook or have to restart the notebook, you can start from here. The preprocessed data has been saved to disk.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import numpy as np
import helper

(source_int_text, target_int_text), (source_vocab_to_int, target_vocab_to_int), _ = helper.load_preprocess()

# %% [markdown]
# ### Check the Version of TensorFlow and Access to GPU
# This will check to make sure you have the correct version of TensorFlow and access to a GPU

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
from distutils.version import LooseVersion
import warnings
import tensorflow as tf

# Check TensorFlow Version
assert LooseVersion(tf.__version__) in [LooseVersion('1.0.0'), LooseVersion('1.0.1')], 'This project requires TensorFlow version 1.0  You are using {}'.format(tf.__version__)
print('TensorFlow Version: {}'.format(tf.__version__))

# Check for a GPU
if not tf.test.gpu_device_name():
    warnings.warn('No GPU found. Please use a GPU to train your neural network.')
else:
    print('Default GPU Device: {}'.format(tf.test.gpu_device_name()))
# Out:
# TensorFlow Version: 1.0.0
# Default GPU Device: /gpu:0

# %% [markdown]
# ## Build the Neural Network
# You'll build the components necessary to build a Sequence-to-Sequence model by implementing the following functions below:
# - `model_inputs`
# - `process_decoding_input`
# - `encoding_layer`
# - `decoding_layer_train`
# - `decoding_layer_infer`
# - `decoding_layer`
# - `seq2seq_model`
#
# ### Input
# Implement the `model_inputs()` function to create TF Placeholders for the Neural Network. It should create the following placeholders:
#
# - Input text placeholder named "input" using the TF Placeholder name parameter with rank 2.
# - Targets placeholder with rank 2.
# - Learning rate placeholder with rank 0.
# - Keep probability placeholder named "keep_prob" using the TF Placeholder name parameter with rank 0.
#
# Return the placeholders in the following the tuple (Input, Targets, Learing Rate, Keep Probability)

# %%
def model_inputs():
    """
    Create TF Placeholders for input, targets, and learning rate.
    :return: Tuple (input, targets, learning rate, keep probability)
    """
    # TODO: Implement Function
    data_input = tf.placeholder(tf.int32, shape=(None, None), name='input')
    data_target = tf.placeholder(tf.int32, shape=(None, None), name='targets')
    learn_rate = tf.placeholder(tf.float32, name='learning_rate')
    keep_prob = tf.placeholder(tf.float32, name='keep_prob')
    
    return (data_input, data_target, learn_rate, keep_prob)

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_model_inputs(model_inputs)
# Out:
# Tests Passed

# %% [markdown]
# ### Process Decoding Input
# Implement `process_decoding_input` using TensorFlow to remove the last word id from each batch in `target_data` and concat the GO ID to the beginning of each batch.

# %%
def process_decoding_input(target_data, target_vocab_to_int, batch_size):
    """
    Preprocess target data for decoding
    :param target_data: Target Placeholder
    :param target_vocab_to_int: Dictionary to go from the target words to an id
    :param batch_size: Batch Size
    :return: Preprocessed target data
    """
    # TODO: Implement Function
    # This is the code from the lesson, any resources tohelp with further understanding of this?
    ending = tf.strided_slice(target_data, [0, 0], [batch_size, -1], [1, 1])
    dec_input = tf.concat([tf.fill([batch_size, 1], target_vocab_to_int['<GO>']), ending], 1)
    return dec_input

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_process_decoding_input(process_decoding_input)
# Out:
# Tests Passed

# %% [markdown]
# ### Encoding
# Implement `encoding_layer()` to create a Encoder RNN layer using [`tf.nn.dynamic_rnn()`](https://www.tensorflow.org/api_docs/python/tf/nn/dynamic_rnn).

# %%
def encoding_layer(rnn_inputs, rnn_size, num_layers, keep_prob):
    """
    Create encoding layer
    :param rnn_inputs: Inputs for the RNN
    :param rnn_size: RNN Size
    :param num_layers: Number of layers
    :param keep_prob: Dropout keep probability
    :return: RNN state
    """
    # TODO: Implement Function
    # Initial state of the LSTM memory.
    stacked_lstm_cells = tf.contrib.rnn.MultiRNNCell([build_rnn_cell(rnn_size, keep_prob) for _ in range(num_layers)], state_is_tuple=True)
    outputs, cells_bw_fw = tf.nn.dynamic_rnn(stacked_lstm_cells, rnn_inputs, dtype=tf.float32)
    
    return cells_bw_fw

# use Tensorflow 1.1 and this olves an error as you will see below
def build_rnn_cell(rnn_size,keep_prob):
    lstm_cell = tf.contrib.rnn.BasicLSTMCell(rnn_size, state_is_tuple=True) 
    # Very usefull
    drop = tf.contrib.rnn.DropoutWrapper(lstm_cell, input_keep_prob=1.0, output_keep_prob=keep_prob)
    return drop

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_encoding_layer(encoding_layer)
# Out:
# Tests Passed

# %% [markdown]
# ### Decoding - Training
# Create training logits using [`tf.contrib.seq2seq.simple_decoder_fn_train()`](https://www.tensorflow.org/versions/r1.0/api_docs/python/tf/contrib/seq2seq/simple_decoder_fn_train) and [`tf.contrib.seq2seq.dynamic_rnn_decoder()`](https://www.tensorflow.org/versions/r1.0/api_docs/python/tf/contrib/seq2seq/dynamic_rnn_decoder).  Apply the `output_fn` to the [`tf.contrib.seq2seq.dynamic_rnn_decoder()`](https://www.tensorflow.org/versions/r1.0/api_docs/python/tf/contrib/seq2seq/dynamic_rnn_decoder) outputs.

# %%
def decoding_layer_train(encoder_state, dec_cell, dec_embed_input, sequence_length, decoding_scope, output_fn, keep_prob):
    """
    Create a decoding layer for training
    :param encoder_state: Encoder State
    :param dec_cell: Decoder RNN Cell
    :param dec_embed_input: Decoder embedded input
    :param sequence_length: Sequence Length
    :param decoding_scope: TensorFlow Variable Scope for decoding
    :param output_fn: Function to apply the output layer
    :param keep_prob: Dropout keep probability
    :return: Train Logits
    """
    # TODO: Implement Function
    train_dynamic_fn = tf.contrib.seq2seq.simple_decoder_fn_train(encoder_state)
    train_outputs, train_final_state, train_final_ctx_state = tf.contrib.seq2seq.dynamic_rnn_decoder(cell=dec_cell, decoder_fn=train_dynamic_fn, inputs=dec_embed_input, sequence_length=sequence_length, scope=decoding_scope)
    train_logits = output_fn(train_outputs)
    
    return train_logits


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_decoding_layer_train(decoding_layer_train)
# Out:
# Tests Passed

# %% [markdown]
# ### Decoding - Inference
# Create inference logits using [`tf.contrib.seq2seq.simple_decoder_fn_inference()`](https://www.tensorflow.org/versions/r1.0/api_docs/python/tf/contrib/seq2seq/simple_decoder_fn_inference) and [`tf.contrib.seq2seq.dynamic_rnn_decoder()`](https://www.tensorflow.org/versions/r1.0/api_docs/python/tf/contrib/seq2seq/dynamic_rnn_decoder).

# %%
def decoding_layer_infer(encoder_state, dec_cell, dec_embeddings, start_of_sequence_id, end_of_sequence_id,
                         maximum_length, vocab_size, decoding_scope, output_fn, keep_prob):
    """
    Create a decoding layer for inference
    :param encoder_state: Encoder state
    :param dec_cell: Decoder RNN Cell
    :param dec_embeddings: Decoder embeddings
    :param start_of_sequence_id: GO ID
    :param end_of_sequence_id: EOS Id
    :param maximum_length: The maximum allowed time steps to decode
    :param vocab_size: Size of vocabulary
    :param decoding_scope: TensorFlow Variable Scope for decoding
    :param output_fn: Function to apply the output layer
    :param keep_prob: Dropout keep probability
    :return: Inference Logits
    """
    # TODO: Implement Function
    infer_dynamic_fn = tf.contrib.seq2seq.simple_decoder_fn_inference(output_fn, encoder_state, 
                                                                      dec_embeddings, start_of_sequence_id, 
                                                                      end_of_sequence_id, maximum_length, vocab_size)
    infer_outputs, infer_final_state, infer_final_ctx_state = tf.contrib.seq2seq.dynamic_rnn_decoder(cell=dec_cell, 
                                                                                                     decoder_fn=infer_dynamic_fn, 
                                                                                                     scope=decoding_scope)
    infer_logits = infer_outputs
    return infer_logits


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_decoding_layer_infer(decoding_layer_infer)
# Out:
# Tests Passed

# %% [markdown]
# ### Build the Decoding Layer
# Implement `decoding_layer()` to create a Decoder RNN layer.
#
# - Create RNN cell for decoding using `rnn_size` and `num_layers`.
# - Create the output fuction using [`lambda`](https://docs.python.org/3/tutorial/controlflow.html#lambda-expressions) to transform it's input, logits, to class logits.
# - Use the your `decoding_layer_train(encoder_state, dec_cell, dec_embed_input, sequence_length, decoding_scope, output_fn, keep_prob)` function to get the training logits.
# - Use your `decoding_layer_infer(encoder_state, dec_cell, dec_embeddings, start_of_sequence_id, end_of_sequence_id, maximum_length, vocab_size, decoding_scope, output_fn, keep_prob)` function to get the inference logits.
#
# Note: You'll need to use [tf.variable_scope](https://www.tensorflow.org/api_docs/python/tf/variable_scope) to share variables between training and inference.

# %%
def decoding_layer(dec_embed_input, dec_embeddings, encoder_state, vocab_size, sequence_length, rnn_size,
                   num_layers, target_vocab_to_int, keep_prob):
    """
    Create decoding layer
    :param dec_embed_input: Decoder embedded input
    :param dec_embeddings: Decoder embeddings
    :param encoder_state: The encoded state
    :param vocab_size: Size of vocabulary
    :param sequence_length: Sequence Length
    :param rnn_size: RNN Size
    :param num_layers: Number of layers
    :param target_vocab_to_int: Dictionary to go from the target words to an id
    :param keep_prob: Dropout keep probability
    :return: Tuple of (Training Logits, Inference Logits)
    """
    # TODO: Implement Function
    # Initial state of the LSTM memory.
    dec_stacked_cells = tf.contrib.rnn.MultiRNNCell([build_rnn_cell(rnn_size, keep_prob) for _ in range(num_layers)], state_is_tuple=True)
    end_seq_id = target_vocab_to_int['<EOS>']
    start_seq_id = target_vocab_to_int['<GO>']
    
    with tf.variable_scope("decoding", reuse=None) as decoding_scope:
        # as shown in problem_unittests.py
        output_fn = lambda x: tf.contrib.layers.fully_connected(x, vocab_size, None, scope=decoding_scope)
    with tf.variable_scope("decoding", reuse=None) as decoding_scope:
        train_logits = decoding_layer_train(encoder_state, dec_stacked_cells,
                                            dec_embed_input, sequence_length, decoding_scope,
                                            output_fn, keep_prob)
    # Error when reuse=True
    with tf.variable_scope("decoding", reuse=True) as decoding_scope:
        infer_logits = decoding_layer_infer(encoder_state, dec_stacked_cells, dec_embeddings, 
                                            start_seq_id, end_seq_id, sequence_length-1, vocab_size, 
                                            decoding_scope, output_fn, keep_prob)
    
    return (train_logits, infer_logits)

# use Tensorflow 1.1 and this olves an error as you will see below
def build_rnn_cell(rnn_size,keep_prob):
    lstm_cell = tf.contrib.rnn.BasicLSTMCell(rnn_size, state_is_tuple=True) 
    # Very usefull
    drop = tf.contrib.rnn.DropoutWrapper(lstm_cell, input_keep_prob=1.0, output_keep_prob=keep_prob)
    return drop


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_decoding_layer(decoding_layer)
# Out:
# Tests Passed

# %% [markdown]
# ### Build the Neural Network
# Apply the functions you implemented above to:
#
# - Apply embedding to the input data for the encoder.
# - Encode the input using your `encoding_layer(rnn_inputs, rnn_size, num_layers, keep_prob)`.
# - Process target data using your `process_decoding_input(target_data, target_vocab_to_int, batch_size)` function.
# - Apply embedding to the target data for the decoder.
# - Decode the encoded input using your `decoding_layer(dec_embed_input, dec_embeddings, encoder_state, vocab_size, sequence_length, rnn_size, num_layers, target_vocab_to_int, keep_prob)`.

# %%
def seq2seq_model(input_data, target_data, keep_prob, batch_size, sequence_length, source_vocab_size, target_vocab_size,
                  enc_embedding_size, dec_embedding_size, rnn_size, num_layers, target_vocab_to_int):
    """
    Build the Sequence-to-Sequence part of the neural network
    :param input_data: Input placeholder
    :param target_data: Target placeholder
    :param keep_prob: Dropout keep probability placeholder
    :param batch_size: Batch Size
    :param sequence_length: Sequence Length
    :param source_vocab_size: Source vocabulary size
    :param target_vocab_size: Target vocabulary size
    :param enc_embedding_size: Decoder embedding size
    :param dec_embedding_size: Encoder embedding size
    :param rnn_size: RNN Size
    :param num_layers: Number of layers
    :param target_vocab_to_int: Dictionary to go from the target words to an id
    :return: Tuple of (Training Logits, Inference Logits)
    """
    # TODO: Implement Function
    #1
    rnn_inputs = tf.contrib.layers.embed_sequence(input_data, source_vocab_size, enc_embedding_size)
    #2
    input_encoded_state = encoding_layer(rnn_inputs, rnn_size, num_layers, keep_prob)
    #3
    target_output = process_decoding_input(target_data, target_vocab_to_int, batch_size)
    #4
    dec_embeds = tf.Variable(tf.random_uniform([target_vocab_size, dec_embedding_size]))
    dec_embeds_input = tf.nn.embedding_lookup(dec_embeds, target_output)
    #5
    train_logits, infer_logits = decoding_layer(dec_embeds_input, dec_embeds, input_encoded_state, target_vocab_size, 
                                                sequence_length, rnn_size, num_layers, target_vocab_to_int, keep_prob)
    return (train_logits, infer_logits)


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_seq2seq_model(seq2seq_model)
# Out:
# Tests Passed

# %% [markdown]
# ## Neural Network Training
# ### Hyperparameters
# Tune the following parameters:
#
# - Set `epochs` to the number of epochs.
# - Set `batch_size` to the batch size.
# - Set `rnn_size` to the size of the RNNs.
# - Set `num_layers` to the number of layers.
# - Set `encoding_embedding_size` to the size of the embedding for the encoder.
# - Set `decoding_embedding_size` to the size of the embedding for the decoder.
# - Set `learning_rate` to the learning rate.
# - Set `keep_probability` to the Dropout keep probability

# %%
# Number of Epochs
epochs = 5
# Batch Size
batch_size = 512
# RNN Size
rnn_size = 512
# Number of Layers
num_layers = 1
# Embedding Size
encoding_embedding_size = 20
decoding_embedding_size = 20
# Learning Rate
learning_rate = 0.01
# Dropout Keep Probability
keep_probability = 0.8

# %% [markdown]
# ### Build the Graph
# Build the graph using the neural network you implemented.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
save_path = 'checkpoints/dev'
(source_int_text, target_int_text), (source_vocab_to_int, target_vocab_to_int), _ = helper.load_preprocess()
max_source_sentence_length = max([len(sentence) for sentence in source_int_text])

train_graph = tf.Graph()
with train_graph.as_default():
    input_data, targets, lr, keep_prob = model_inputs()
    sequence_length = tf.placeholder_with_default(max_source_sentence_length, None, name='sequence_length')
    input_shape = tf.shape(input_data)
    
    train_logits, inference_logits = seq2seq_model(
        tf.reverse(input_data, [-1]), targets, keep_prob, batch_size, sequence_length, len(source_vocab_to_int), len(target_vocab_to_int),
        encoding_embedding_size, decoding_embedding_size, rnn_size, num_layers, target_vocab_to_int)

    tf.identity(inference_logits, 'logits')
    with tf.name_scope("optimization"):
        # Loss function
        cost = tf.contrib.seq2seq.sequence_loss(
            train_logits,
            targets,
            tf.ones([input_shape[0], sequence_length]))

        # Optimizer
        optimizer = tf.train.AdamOptimizer(lr)

        # Gradient Clipping
        gradients = optimizer.compute_gradients(cost)
        capped_gradients = [(tf.clip_by_value(grad, -1., 1.), var) for grad, var in gradients if grad is not None]
        train_op = optimizer.apply_gradients(capped_gradients)

# %% [markdown]
# ### Train
# Train the neural network on the preprocessed data. If you have a hard time getting a good loss, check the forums to see if anyone is having the same problem.

# %%
import matplotlib.pyplot as plt

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import time

def get_accuracy(target, logits):
    """
    Calculate accuracy
    """
    max_seq = max(target.shape[1], logits.shape[1])
    if max_seq - target.shape[1]:
        target = np.pad(
            target,
            [(0,0),(0,max_seq - target.shape[1])],
            'constant')
    if max_seq - logits.shape[1]:
        logits = np.pad(
            logits,
            [(0,0),(0,max_seq - logits.shape[1]), (0,0)],
            'constant')

    return np.mean(np.equal(target, np.argmax(logits, 2)))

train_source = source_int_text[batch_size:]
train_target = target_int_text[batch_size:]

valid_source = helper.pad_sentence_batch(source_int_text[:batch_size])
valid_target = helper.pad_sentence_batch(target_int_text[:batch_size])

with tf.Session(graph=train_graph) as sess:
    sess.run(tf.global_variables_initializer())
    
    losses = {'train':[], 'validation':[]}
    for epoch_i in range(epochs):
        for batch_i, (source_batch, target_batch) in enumerate(
                helper.batch_data(train_source, train_target, batch_size)):
            start_time = time.time()
            
            _, loss = sess.run(
                [train_op, cost],
                {input_data: source_batch,
                 targets: target_batch,
                 lr: learning_rate,
                 sequence_length: target_batch.shape[1],
                 keep_prob: keep_probability})
            
            batch_train_logits = sess.run(
                inference_logits,
                {input_data: source_batch, keep_prob: 1.0})
            batch_valid_logits = sess.run(
                inference_logits,
                {input_data: valid_source, keep_prob: 1.0})
                
            train_acc = get_accuracy(target_batch, batch_train_logits)
            valid_acc = get_accuracy(np.array(valid_target), batch_valid_logits)
            end_time = time.time()
            print('Epoch {:>3} Batch {:>4}/{} - Train Accuracy: {:>6.3f}, Validation Accuracy: {:>6.3f}, Loss: {:>6.3f}'
                  .format(epoch_i, batch_i, len(source_int_text) // batch_size, train_acc, valid_acc, loss))
            losses['train'].append(train_acc)
            losses['validation'].append(valid_acc)

    #plot accuracy
    plt.plot(losses['train'], label='Training loss')
    plt.plot(losses['validation'], label='Validation loss')
    plt.legend()
    # Save Model
    saver = tf.train.Saver()
    saver.save(sess, save_path)
    print('Model Trained and Saved')
# Out:
# Epoch   0 Batch    0/269 - Train Accuracy:  0.242, Validation Accuracy:  0.310, Loss:  5.876
# Epoch   0 Batch    1/269 - Train Accuracy:  0.136, Validation Accuracy:  0.216, Loss:  5.505
# Epoch   0 Batch    2/269 - Train Accuracy:  0.260, Validation Accuracy:  0.302, Loss:  6.277
# Epoch   0 Batch    3/269 - Train Accuracy:  0.169, Validation Accuracy:  0.246, Loss:  5.705
# Epoch   0 Batch    4/269 - Train Accuracy:  0.234, Validation Accuracy:  0.311, Loss:  5.088
# Epoch   0 Batch    5/269 - Train Accuracy:  0.246, Validation Accuracy:  0.316, Loss:  4.725
# Epoch   0 Batch    6/269 - Train Accuracy:  0.304, Validation Accuracy:  0.334, Loss:  3.980
# Epoch   0 Batch    7/269 - Train Accuracy:  0.314, Validation Accuracy:  0.345, Loss:  3.551
# Epoch   0 Batch    8/269 - Train Accuracy:  0.285, Validation Accuracy:  0.349, Loss:  3.722
# Epoch   0 Batch    9/269 - Train Accuracy:  0.305, Validation Accuracy:  0.347, Loss:  3.420
# Epoch   0 Batch   10/269 - Train Accuracy:  0.270, Validation Accuracy:  0.343, Loss:  3.415
# Epoch   0 Batch   11/269 - Train Accuracy:  0.309, Validation Accuracy:  0.346, Loss:  3.321
# Epoch   0 Batch   12/269 - Train Accuracy:  0.311, Validation Accuracy:  0.372, Loss:  3.329
# Epoch   0 Batch   13/269 - Train Accuracy:  0.368, Validation Accuracy:  0.363, Loss:  2.927
# Epoch   0 Batch   14/269 - Train Accuracy:  0.354, Validation Accuracy:  0.387, Loss:  3.014
# Epoch   0 Batch   15/269 - Train Accuracy:  0.338, Validation Accuracy:  0.377, Loss:  2.950
# Epoch   0 Batch   16/269 - Train Accuracy:  0.351, Validation Accuracy:  0.382, Loss:  2.920
# Epoch   0 Batch   17/269 - Train Accuracy:  0.347, Validation Accuracy:  0.381, Loss:  2.899
# Epoch   0 Batch   18/269 - Train Accuracy:  0.311, Validation Accuracy:  0.373, Loss:  2.889
# Epoch   0 Batch   19/269 - Train Accuracy:  0.387, Validation Accuracy:  0.386, Loss:  2.663
# Epoch   0 Batch   20/269 - Train Accuracy:  0.340, Validation Accuracy:  0.389, Loss:  2.815
# Epoch   0 Batch   21/269 - Train Accuracy:  0.335, Validation Accuracy:  0.388, Loss:  2.804
# Epoch   0 Batch   22/269 - Train Accuracy:  0.361, Validation Accuracy:  0.391, Loss:  2.668
# Epoch   0 Batch   23/269 - Train Accuracy:  0.368, Validation Accuracy:  0.396, Loss:  2.641
# Epoch   0 Batch   24/269 - Train Accuracy:  0.332, Validation Accuracy:  0.387, Loss:  2.697
# Epoch   0 Batch   25/269 - Train Accuracy:  0.334, Validation Accuracy:  0.393, Loss:  2.691
# Epoch   0 Batch   26/269 - Train Accuracy:  0.387, Validation Accuracy:  0.389, Loss:  2.376
# Epoch   0 Batch   27/269 - Train Accuracy:  0.368, Validation Accuracy:  0.395, Loss:  2.515
# Epoch   0 Batch   28/269 - Train Accuracy:  0.323, Validation Accuracy:  0.387, Loss:  2.575
# Epoch   0 Batch   29/269 - Train Accuracy:  0.332, Validation Accuracy:  0.392, Loss:  2.530
# Epoch   0 Batch   30/269 - Train Accuracy:  0.337, Validation Accuracy:  0.371, Loss:  2.390
# Epoch   0 Batch   31/269 - Train Accuracy:  0.330, Validation Accuracy:  0.375, Loss:  2.379
# Epoch   0 Batch   32/269 - Train Accuracy:  0.355, Validation Accuracy:  0.390, Loss:  2.322
# Epoch   0 Batch   33/269 - Train Accuracy:  0.348, Validation Accuracy:  0.374, Loss:  2.260
# Epoch   0 Batch   34/269 - Train Accuracy:  0.342, Validation Accuracy:  0.374, Loss:  2.191
# Epoch   0 Batch   35/269 - Train Accuracy:  0.347, Validation Accuracy:  0.373, Loss:  2.165
# Epoch   0 Batch   36/269 - Train Accuracy:  0.344, Validation Accuracy:  0.374, Loss:  2.146
# Epoch   0 Batch   37/269 - Train Accuracy:  0.344, Validation Accuracy:  0.374, Loss:  2.118
# Epoch   0 Batch   38/269 - Train Accuracy:  0.336, Validation Accuracy:  0.374, Loss:  2.071
# Epoch   0 Batch   39/269 - Train Accuracy:  0.349, Validation Accuracy:  0.373, Loss:  1.980
# Epoch   0 Batch   40/269 - Train Accuracy:  0.312, Validation Accuracy:  0.374, Loss:  2.020
# Epoch   0 Batch   41/269 - Train Accuracy:  0.331, Validation Accuracy:  0.365, Loss:  1.923
# Epoch   0 Batch   42/269 - Train Accuracy:  0.387, Validation Accuracy:  0.384, Loss:  1.796
# Epoch   0 Batch   43/269 - Train Accuracy:  0.299, Validation Accuracy:  0.365, Loss:  1.926
# Epoch   0 Batch   44/269 - Train Accuracy:  0.363, Validation Accuracy:  0.385, Loss:  1.796
# Epoch   0 Batch   45/269 - Train Accuracy:  0.321, Validation Accuracy:  0.381, Loss:  1.831
# Epoch   0 Batch   46/269 - Train Accuracy:  0.343, Validation Accuracy:  0.390, Loss:  1.772
# Epoch   0 Batch   47/269 - Train Accuracy:  0.379, Validation Accuracy:  0.368, Loss:  1.564
# Epoch   0 Batch   48/269 - Train Accuracy:  0.325, Validation Accuracy:  0.354, Loss:  1.575
# Epoch   0 Batch   49/269 - Train Accuracy:  0.300, Validation Accuracy:  0.365, Loss:  1.649
# Epoch   0 Batch   50/269 - Train Accuracy:  0.306, Validation Accuracy:  0.370, Loss:  1.613
# Epoch   0 Batch   51/269 - Train Accuracy:  0.339, Validation Accuracy:  0.366, Loss:  1.527
# Epoch   0 Batch   52/269 - Train Accuracy:  0.346, Validation Accuracy:  0.377, Loss:  1.426
# Epoch   0 Batch   53/269 - Train Accuracy:  0.323, Validation Accuracy:  0.382, Loss:  1.490
# Epoch   0 Batch   54/269 - Train Accuracy:  0.353, Validation Accuracy:  0.406, Loss:  1.447
# Epoch   0 Batch   55/269 - Train Accuracy:  0.399, Validation Accuracy:  0.419, Loss:  1.330
# Epoch   0 Batch   56/269 - Train Accuracy:  0.391, Validation Accuracy:  0.405, Loss:  1.322
# Epoch   0 Batch   57/269 - Train Accuracy:  0.390, Validation Accuracy:  0.402, Loss:  1.295
# Epoch   0 Batch   58/269 - Train Accuracy:  0.435, Validation Accuracy:  0.448, Loss:  1.244
# Epoch   0 Batch   59/269 - Train Accuracy:  0.432, Validation Accuracy:  0.452, Loss:  1.190
# Epoch   0 Batch   60/269 - Train Accuracy:  0.441, Validation Accuracy:  0.447, Loss:  1.139
# Epoch   0 Batch   61/269 - Train Accuracy:  0.452, Validation Accuracy:  0.445, Loss:  1.108
# Epoch   0 Batch   62/269 - Train Accuracy:  0.463, Validation Accuracy:  0.442, Loss:  1.107
# Epoch   0 Batch   63/269 - Train Accuracy:  0.432, Validation Accuracy:  0.444, Loss:  1.131
# Epoch   0 Batch   64/269 - Train Accuracy:  0.422, Validation Accuracy:  0.449, Loss:  1.093
# Epoch   0 Batch   65/269 - Train Accuracy:  0.425, Validation Accuracy:  0.452, Loss:  1.059
# Epoch   0 Batch   66/269 - Train Accuracy:  0.440, Validation Accuracy:  0.447, Loss:  1.020
# Epoch   0 Batch   67/269 - Train Accuracy:  0.432, Validation Accuracy:  0.454, Loss:  1.060
# Epoch   0 Batch   68/269 - Train Accuracy:  0.427, Validation Accuracy:  0.460, Loss:  1.044
# Epoch   0 Batch   69/269 - Train Accuracy:  0.412, Validation Accuracy:  0.460, Loss:  1.106
# Epoch   0 Batch   70/269 - Train Accuracy:  0.448, Validation Accuracy:  0.461, Loss:  1.010
# Epoch   0 Batch   71/269 - Train Accuracy:  0.423, Validation Accuracy:  0.462, Loss:  1.019
# Epoch   0 Batch   72/269 - Train Accuracy:  0.456, Validation Accuracy:  0.463, Loss:  0.954
# Epoch   0 Batch   73/269 - Train Accuracy:  0.464, Validation Accuracy:  0.467, Loss:  0.980
# Epoch   0 Batch   74/269 - Train Accuracy:  0.443, Validation Accuracy:  0.465, Loss:  0.958
# Epoch   0 Batch   75/269 - Train Accuracy:  0.455, Validation Accuracy:  0.476, Loss:  0.920
# Epoch   0 Batch   76/269 - Train Accuracy:  0.447, Validation Accuracy:  0.470, Loss:  0.932
# Epoch   0 Batch   77/269 - Train Accuracy:  0.473, Validation Accuracy:  0.475, Loss:  0.910
# Epoch   0 Batch   78/269 - Train Accuracy:  0.448, Validation Accuracy:  0.468, Loss:  0.896
# Epoch   0 Batch   79/269 - Train Accuracy:  0.448, Validation Accuracy:  0.464, Loss:  0.872
# Epoch   0 Batch   80/269 - Train Accuracy:  0.472, Validation Accuracy:  0.470, Loss:  0.875
# Epoch   0 Batch   81/269 - Train Accuracy:  0.457, Validation Accuracy:  0.474, Loss:  0.896
# Epoch   0 Batch   82/269 - Train Accuracy:  0.487, Validation Accuracy:  0.492, Loss:  0.843
# Epoch   0 Batch   83/269 - Train Accuracy:  0.486, Validation Accuracy:  0.492, Loss:  0.867
# Epoch   0 Batch   84/269 - Train Accuracy:  0.468, Validation Accuracy:  0.481, Loss:  0.835
# Epoch   0 Batch   85/269 - Train Accuracy:  0.485, Validation Accuracy:  0.490, Loss:  0.835
# Epoch   0 Batch   86/269 - Train Accuracy:  0.465, Validation Accuracy:  0.488, Loss:  0.823
# Epoch   0 Batch   87/269 - Train Accuracy:  0.436, Validation Accuracy:  0.487, Loss:  0.874
# Epoch   0 Batch   88/269 - Train Accuracy:  0.496, Validation Accuracy:  0.501, Loss:  0.820
# Epoch   0 Batch   89/269 - Train Accuracy:  0.485, Validation Accuracy:  0.484, Loss:  0.817
# Epoch   0 Batch   90/269 - Train Accuracy:  0.441, Validation Accuracy:  0.483, Loss:  0.855
# Epoch   0 Batch   91/269 - Train Accuracy:  0.463, Validation Accuracy:  0.489, Loss:  0.785
# Epoch   0 Batch   92/269 - Train Accuracy:  0.477, Validation Accuracy:  0.493, Loss:  0.791
# Epoch   0 Batch   93/269 - Train Accuracy:  0.498, Validation Accuracy:  0.501, Loss:  0.759
# Epoch   0 Batch   94/269 - Train Accuracy:  0.471, Validation Accuracy:  0.489, Loss:  0.808
# Epoch   0 Batch   95/269 - Train Accuracy:  0.468, Validation Accuracy:  0.474, Loss:  0.779
# Epoch   0 Batch   96/269 - Train Accuracy:  0.482, Validation Accuracy:  0.500, Loss:  0.770
# Epoch   0 Batch   97/269 - Train Accuracy:  0.486, Validation Accuracy:  0.500, Loss:  0.769
# Epoch   0 Batch   98/269 - Train Accuracy:  0.515, Validation Accuracy:  0.513, Loss:  0.765
# Epoch   0 Batch   99/269 - Train Accuracy:  0.472, Validation Accuracy:  0.510, Loss:  0.786
# Epoch   0 Batch  100/269 - Train Accuracy:  0.506, Validation Accuracy:  0.502, Loss:  0.755
# Epoch   0 Batch  101/269 - Train Accuracy:  0.453, Validation Accuracy:  0.494, Loss:  0.805
# Epoch   0 Batch  102/269 - Train Accuracy:  0.484, Validation Accuracy:  0.493, Loss:  0.754
# Epoch   0 Batch  103/269 - Train Accuracy:  0.476, Validation Accuracy:  0.505, Loss:  0.745
# Epoch   0 Batch  104/269 - Train Accuracy:  0.498, Validation Accuracy:  0.505, Loss:  0.745
# Epoch   0 Batch  105/269 - Train Accuracy:  0.489, Validation Accuracy:  0.506, Loss:  0.755
# Epoch   0 Batch  106/269 - Train Accuracy:  0.481, Validation Accuracy:  0.499, Loss:  0.733
# Epoch   0 Batch  107/269 - Train Accuracy:  0.452, Validation Accuracy:  0.500, Loss:  0.770
# Epoch   0 Batch  108/269 - Train Accuracy:  0.495, Validation Accuracy:  0.498, Loss:  0.728
# Epoch   0 Batch  109/269 - Train Accuracy:  0.487, Validation Accuracy:  0.505, Loss:  0.740
# Epoch   0 Batch  110/269 - Train Accuracy:  0.495, Validation Accuracy:  0.503, Loss:  0.709
# Epoch   0 Batch  111/269 - Train Accuracy:  0.467, Validation Accuracy:  0.509, Loss:  0.766
# Epoch   0 Batch  112/269 - Train Accuracy:  0.516, Validation Accuracy:  0.524, Loss:  0.719
# Epoch   0 Batch  113/269 - Train Accuracy:  0.521, Validation Accuracy:  0.520, Loss:  0.687
# Epoch   0 Batch  114/269 - Train Accuracy:  0.492, Validation Accuracy:  0.518, Loss:  0.706
# Epoch   0 Batch  115/269 - Train Accuracy:  0.495, Validation Accuracy:  0.520, Loss:  0.744
# Epoch   0 Batch  116/269 - Train Accuracy:  0.516, Validation Accuracy:  0.520, Loss:  0.720
# Epoch   0 Batch  117/269 - Train Accuracy:  0.498, Validation Accuracy:  0.524, Loss:  0.703
# Epoch   0 Batch  118/269 - Train Accuracy:  0.526, Validation Accuracy:  0.519, Loss:  0.689
# Epoch   0 Batch  119/269 - Train Accuracy:  0.494, Validation Accuracy:  0.519, Loss:  0.727
# Epoch   0 Batch  120/269 - Train Accuracy:  0.484, Validation Accuracy:  0.508, Loss:  0.721
# Epoch   0 Batch  121/269 - Train Accuracy:  0.494, Validation Accuracy:  0.498, Loss:  0.693
# Epoch   0 Batch  122/269 - Train Accuracy:  0.485, Validation Accuracy:  0.490, Loss:  0.686
# Epoch   0 Batch  123/269 - Train Accuracy:  0.469, Validation Accuracy:  0.508, Loss:  0.719
# Epoch   0 Batch  124/269 - Train Accuracy:  0.511, Validation Accuracy:  0.521, Loss:  0.675
# Epoch   0 Batch  125/269 - Train Accuracy:  0.515, Validation Accuracy:  0.523, Loss:  0.684
# Epoch   0 Batch  126/269 - Train Accuracy:  0.528, Validation Accuracy:  0.521, Loss:  0.683
# Epoch   0 Batch  127/269 - Train Accuracy:  0.502, Validation Accuracy:  0.525, Loss:  0.704
# Epoch   0 Batch  128/269 - Train Accuracy:  0.536, Validation Accuracy:  0.528, Loss:  0.683
# Epoch   0 Batch  129/269 - Train Accuracy:  0.513, Validation Accuracy:  0.536, Loss:  0.681
# Epoch   0 Batch  130/269 - Train Accuracy:  0.500, Validation Accuracy:  0.535, Loss:  0.708
# Epoch   0 Batch  131/269 - Train Accuracy:  0.508, Validation Accuracy:  0.535, Loss:  0.707
# Epoch   0 Batch  132/269 - Train Accuracy:  0.501, Validation Accuracy:  0.516, Loss:  0.693
# Epoch   0 Batch  133/269 - Train Accuracy:  0.507, Validation Accuracy:  0.525, Loss:  0.664
# Epoch   0 Batch  134/269 - Train Accuracy:  0.502, Validation Accuracy:  0.529, Loss:  0.692
# Epoch   0 Batch  135/269 - Train Accuracy:  0.497, Validation Accuracy:  0.527, Loss:  0.719
# Epoch   0 Batch  136/269 - Train Accuracy:  0.492, Validation Accuracy:  0.531, Loss:  0.713
# Epoch   0 Batch  137/269 - Train Accuracy:  0.510, Validation Accuracy:  0.526, Loss:  0.706
# Epoch   0 Batch  138/269 - Train Accuracy:  0.506, Validation Accuracy:  0.517, Loss:  0.699
# Epoch   0 Batch  139/269 - Train Accuracy:  0.535, Validation Accuracy:  0.523, Loss:  0.648
# Epoch   0 Batch  140/269 - Train Accuracy:  0.545, Validation Accuracy:  0.539, Loss:  0.676
# Epoch   0 Batch  141/269 - Train Accuracy:  0.530, Validation Accuracy:  0.548, Loss:  0.686
# Epoch   0 Batch  142/269 - Train Accuracy:  0.542, Validation Accuracy:  0.547, Loss:  0.641
# Epoch   0 Batch  143/269 - Train Accuracy:  0.543, Validation Accuracy:  0.551, Loss:  0.657
# Epoch   0 Batch  144/269 - Train Accuracy:  0.554, Validation Accuracy:  0.551, Loss:  0.626
# Epoch   0 Batch  145/269 - Train Accuracy:  0.538, Validation Accuracy:  0.541, Loss:  0.651
# Epoch   0 Batch  146/269 - Train Accuracy:  0.534, Validation Accuracy:  0.546, Loss:  0.640
# Epoch   0 Batch  147/269 - Train Accuracy:  0.552, Validation Accuracy:  0.548, Loss:  0.631
# Epoch   0 Batch  148/269 - Train Accuracy:  0.532, Validation Accuracy:  0.546, Loss:  0.644
# Epoch   0 Batch  149/269 - Train Accuracy:  0.536, Validation Accuracy:  0.550, Loss:  0.657
# Epoch   0 Batch  150/269 - Train Accuracy:  0.550, Validation Accuracy:  0.550, Loss:  0.649
# Epoch   0 Batch  151/269 - Train Accuracy:  0.562, Validation Accuracy:  0.540, Loss:  0.615
# Epoch   0 Batch  152/269 - Train Accuracy:  0.538, Validation Accuracy:  0.546, Loss:  0.650
# Epoch   0 Batch  153/269 - Train Accuracy:  0.541, Validation Accuracy:  0.547, Loss:  0.638
# Epoch   0 Batch  154/269 - Train Accuracy:  0.541, Validation Accuracy:  0.551, Loss:  0.659
# Epoch   0 Batch  155/269 - Train Accuracy:  0.565, Validation Accuracy:  0.555, Loss:  0.602
# Epoch   0 Batch  156/269 - Train Accuracy:  0.544, Validation Accuracy:  0.561, Loss:  0.669
# Epoch   0 Batch  157/269 - Train Accuracy:  0.559, Validation Accuracy:  0.561, Loss:  0.631
# Epoch   0 Batch  158/269 - Train Accuracy:  0.542, Validation Accuracy:  0.552, Loss:  0.633
# Epoch   0 Batch  159/269 - Train Accuracy:  0.561, Validation Accuracy:  0.556, Loss:  0.631
# Epoch   0 Batch  160/269 - Train Accuracy:  0.556, Validation Accuracy:  0.563, Loss:  0.616
# Epoch   0 Batch  161/269 - Train Accuracy:  0.557, Validation Accuracy:  0.565, Loss:  0.624
# Epoch   0 Batch  162/269 - Train Accuracy:  0.571, Validation Accuracy:  0.564, Loss:  0.628
# Epoch   0 Batch  163/269 - Train Accuracy:  0.573, Validation Accuracy:  0.566, Loss:  0.624
# Epoch   0 Batch  164/269 - Train Accuracy:  0.565, Validation Accuracy:  0.564, Loss:  0.613
# Epoch   0 Batch  165/269 - Train Accuracy:  0.546, Validation Accuracy:  0.569, Loss:  0.650
# Epoch   0 Batch  166/269 - Train Accuracy:  0.574, Validation Accuracy:  0.555, Loss:  0.590
# Epoch   0 Batch  167/269 - Train Accuracy:  0.551, Validation Accuracy:  0.549, Loss:  0.614
# Epoch   0 Batch  168/269 - Train Accuracy:  0.557, Validation Accuracy:  0.561, Loss:  0.620
# Epoch   0 Batch  169/269 - Train Accuracy:  0.547, Validation Accuracy:  0.546, Loss:  0.621
# Epoch   0 Batch  170/269 - Train Accuracy:  0.563, Validation Accuracy:  0.550, Loss:  0.600
# Epoch   0 Batch  171/269 - Train Accuracy:  0.550, Validation Accuracy:  0.558, Loss:  0.645
# Epoch   0 Batch  172/269 - Train Accuracy:  0.561, Validation Accuracy:  0.567, Loss:  0.621
# Epoch   0 Batch  173/269 - Train Accuracy:  0.573, Validation Accuracy:  0.569, Loss:  0.595
# Epoch   0 Batch  174/269 - Train Accuracy:  0.561, Validation Accuracy:  0.582, Loss:  0.611
# Epoch   0 Batch  175/269 - Train Accuracy:  0.580, Validation Accuracy:  0.582, Loss:  0.624
# Epoch   0 Batch  176/269 - Train Accuracy:  0.564, Validation Accuracy:  0.583, Loss:  0.631
# Epoch   0 Batch  177/269 - Train Accuracy:  0.592, Validation Accuracy:  0.591, Loss:  0.575
# Epoch   0 Batch  178/269 - Train Accuracy:  0.574, Validation Accuracy:  0.580, Loss:  0.617
# Epoch   0 Batch  179/269 - Train Accuracy:  0.590, Validation Accuracy:  0.589, Loss:  0.600
# Epoch   0 Batch  180/269 - Train Accuracy:  0.585, Validation Accuracy:  0.590, Loss:  0.596
# Epoch   0 Batch  181/269 - Train Accuracy:  0.577, Validation Accuracy:  0.585, Loss:  0.589
# Epoch   0 Batch  182/269 - Train Accuracy:  0.596, Validation Accuracy:  0.597, Loss:  0.591
# Epoch   0 Batch  183/269 - Train Accuracy:  0.640, Validation Accuracy:  0.588, Loss:  0.520
# Epoch   0 Batch  184/269 - Train Accuracy:  0.558, Validation Accuracy:  0.587, Loss:  0.615
# Epoch   0 Batch  185/269 - Train Accuracy:  0.585, Validation Accuracy:  0.596, Loss:  0.582
# Epoch   0 Batch  186/269 - Train Accuracy:  0.571, Validation Accuracy:  0.585, Loss:  0.604
# Epoch   0 Batch  187/269 - Train Accuracy:  0.576, Validation Accuracy:  0.581, Loss:  0.582
# Epoch   0 Batch  188/269 - Train Accuracy:  0.603, Validation Accuracy:  0.593, Loss:  0.574
# Epoch   0 Batch  189/269 - Train Accuracy:  0.589, Validation Accuracy:  0.591, Loss:  0.565
# Epoch   0 Batch  190/269 - Train Accuracy:  0.575, Validation Accuracy:  0.600, Loss:  0.576
# Epoch   0 Batch  191/269 - Train Accuracy:  0.603, Validation Accuracy:  0.603, Loss:  0.568
# Epoch   0 Batch  192/269 - Train Accuracy:  0.598, Validation Accuracy:  0.610, Loss:  0.572
# Epoch   0 Batch  193/269 - Train Accuracy:  0.603, Validation Accuracy:  0.602, Loss:  0.570
# Epoch   0 Batch  194/269 - Train Accuracy:  0.611, Validation Accuracy:  0.602, Loss:  0.576
# Epoch   0 Batch  195/269 - Train Accuracy:  0.604, Validation Accuracy:  0.592, Loss:  0.572
# Epoch   0 Batch  196/269 - Train Accuracy:  0.582, Validation Accuracy:  0.600, Loss:  0.576
# Epoch   0 Batch  197/269 - Train Accuracy:  0.571, Validation Accuracy:  0.592, Loss:  0.594
# Epoch   0 Batch  198/269 - Train Accuracy:  0.554, Validation Accuracy:  0.583, Loss:  0.591
# Epoch   0 Batch  199/269 - Train Accuracy:  0.577, Validation Accuracy:  0.589, Loss:  0.576
# Epoch   0 Batch  200/269 - Train Accuracy:  0.583, Validation Accuracy:  0.604, Loss:  0.590
# Epoch   0 Batch  201/269 - Train Accuracy:  0.608, Validation Accuracy:  0.609, Loss:  0.550
# Epoch   0 Batch  202/269 - Train Accuracy:  0.598, Validation Accuracy:  0.614, Loss:  0.565
# Epoch   0 Batch  203/269 - Train Accuracy:  0.597, Validation Accuracy:  0.615, Loss:  0.591
# Epoch   0 Batch  204/269 - Train Accuracy:  0.581, Validation Accuracy:  0.602, Loss:  0.588
# Epoch   0 Batch  205/269 - Train Accuracy:  0.598, Validation Accuracy:  0.595, Loss:  0.546
# Epoch   0 Batch  206/269 - Train Accuracy:  0.567, Validation Accuracy:  0.586, Loss:  0.577
# Epoch   0 Batch  207/269 - Train Accuracy:  0.599, Validation Accuracy:  0.596, Loss:  0.543
# Epoch   0 Batch  208/269 - Train Accuracy:  0.584, Validation Accuracy:  0.608, Loss:  0.578
# Epoch   0 Batch  209/269 - Train Accuracy:  0.616, Validation Accuracy:  0.629, Loss:  0.563
# Epoch   0 Batch  210/269 - Train Accuracy:  0.619, Validation Accuracy:  0.618, Loss:  0.541
# Epoch   0 Batch  211/269 - Train Accuracy:  0.611, Validation Accuracy:  0.616, Loss:  0.557
# Epoch   0 Batch  212/269 - Train Accuracy:  0.618, Validation Accuracy:  0.624, Loss:  0.550
# Epoch   0 Batch  213/269 - Train Accuracy:  0.609, Validation Accuracy:  0.620, Loss:  0.551
# Epoch   0 Batch  214/269 - Train Accuracy:  0.626, Validation Accuracy:  0.633, Loss:  0.540
# Epoch   0 Batch  215/269 - Train Accuracy:  0.646, Validation Accuracy:  0.635, Loss:  0.509
# Epoch   0 Batch  216/269 - Train Accuracy:  0.588, Validation Accuracy:  0.626, Loss:  0.569
# Epoch   0 Batch  217/269 - Train Accuracy:  0.592, Validation Accuracy:  0.637, Loss:  0.569
# Epoch   0 Batch  218/269 - Train Accuracy:  0.603, Validation Accuracy:  0.618, Loss:  0.571
# Epoch   0 Batch  219/269 - Train Accuracy:  0.610, Validation Accuracy:  0.627, Loss:  0.570
# Epoch   0 Batch  220/269 - Train Accuracy:  0.627, Validation Accuracy:  0.630, Loss:  0.520
# Epoch   0 Batch  221/269 - Train Accuracy:  0.648, Validation Accuracy:  0.637, Loss:  0.530
# Epoch   0 Batch  222/269 - Train Accuracy:  0.643, Validation Accuracy:  0.636, Loss:  0.529
# Epoch   0 Batch  223/269 - Train Accuracy:  0.622, Validation Accuracy:  0.632, Loss:  0.540
# Epoch   0 Batch  224/269 - Train Accuracy:  0.626, Validation Accuracy:  0.620, Loss:  0.543
# Epoch   0 Batch  225/269 - Train Accuracy:  0.605, Validation Accuracy:  0.620, Loss:  0.544
# Epoch   0 Batch  226/269 - Train Accuracy:  0.628, Validation Accuracy:  0.635, Loss:  0.542
# Epoch   0 Batch  227/269 - Train Accuracy:  0.684, Validation Accuracy:  0.639, Loss:  0.468
# Epoch   0 Batch  228/269 - Train Accuracy:  0.635, Validation Accuracy:  0.646, Loss:  0.532
# Epoch   0 Batch  229/269 - Train Accuracy:  0.626, Validation Accuracy:  0.634, Loss:  0.526
# Epoch   0 Batch  230/269 - Train Accuracy:  0.622, Validation Accuracy:  0.628, Loss:  0.532
# Epoch   0 Batch  231/269 - Train Accuracy:  0.596, Validation Accuracy:  0.636, Loss:  0.552
# Epoch   0 Batch  232/269 - Train Accuracy:  0.597, Validation Accuracy:  0.629, Loss:  0.564
# Epoch   0 Batch  233/269 - Train Accuracy:  0.641, Validation Accuracy:  0.642, Loss:  0.528
# Epoch   0 Batch  234/269 - Train Accuracy:  0.623, Validation Accuracy:  0.640, Loss:  0.527
# Epoch   0 Batch  235/269 - Train Accuracy:  0.635, Validation Accuracy:  0.633, Loss:  0.507
# Epoch   0 Batch  236/269 - Train Accuracy:  0.625, Validation Accuracy:  0.631, Loss:  0.522
# Epoch   0 Batch  237/269 - Train Accuracy:  0.632, Validation Accuracy:  0.644, Loss:  0.522
# Epoch   0 Batch  238/269 - Train Accuracy:  0.650, Validation Accuracy:  0.645, Loss:  0.506
# Epoch   0 Batch  239/269 - Train Accuracy:  0.630, Validation Accuracy:  0.636, Loss:  0.521
# Epoch   0 Batch  240/269 - Train Accuracy:  0.669, Validation Accuracy:  0.635, Loss:  0.463
# Epoch   0 Batch  241/269 - Train Accuracy:  0.643, Validation Accuracy:  0.650, Loss:  0.516
# Epoch   0 Batch  242/269 - Train Accuracy:  0.618, Validation Accuracy:  0.643, Loss:  0.521
# Epoch   0 Batch  243/269 - Train Accuracy:  0.656, Validation Accuracy:  0.643, Loss:  0.489
# Epoch   0 Batch  244/269 - Train Accuracy:  0.618, Validation Accuracy:  0.635, Loss:  0.522
# Epoch   0 Batch  245/269 - Train Accuracy:  0.621, Validation Accuracy:  0.650, Loss:  0.537
# Epoch   0 Batch  246/269 - Train Accuracy:  0.630, Validation Accuracy:  0.652, Loss:  0.506
# Epoch   0 Batch  247/269 - Train Accuracy:  0.637, Validation Accuracy:  0.651, Loss:  0.525
# Epoch   0 Batch  248/269 - Train Accuracy:  0.629, Validation Accuracy:  0.641, Loss:  0.501
# Epoch   0 Batch  249/269 - Train Accuracy:  0.670, Validation Accuracy:  0.659, Loss:  0.472
# Epoch   0 Batch  250/269 - Train Accuracy:  0.650, Validation Accuracy:  0.665, Loss:  0.502
# Epoch   0 Batch  251/269 - Train Accuracy:  0.678, Validation Accuracy:  0.674, Loss:  0.489
# Epoch   0 Batch  252/269 - Train Accuracy:  0.660, Validation Accuracy:  0.672, Loss:  0.500
# Epoch   0 Batch  253/269 - Train Accuracy:  0.648, Validation Accuracy:  0.663, Loss:  0.506
# Epoch   0 Batch  254/269 - Train Accuracy:  0.648, Validation Accuracy:  0.656, Loss:  0.507
# Epoch   0 Batch  255/269 - Train Accuracy:  0.668, Validation Accuracy:  0.662, Loss:  0.468
# Epoch   0 Batch  256/269 - Train Accuracy:  0.638, Validation Accuracy:  0.661, Loss:  0.501
# Epoch   0 Batch  257/269 - Train Accuracy:  0.626, Validation Accuracy:  0.642, Loss:  0.506
# Epoch   0 Batch  258/269 - Train Accuracy:  0.637, Validation Accuracy:  0.636, Loss:  0.489
# Epoch   0 Batch  259/269 - Train Accuracy:  0.657, Validation Accuracy:  0.646, Loss:  0.483
# Epoch   0 Batch  260/269 - Train Accuracy:  0.642, Validation Accuracy:  0.662, Loss:  0.508
# Epoch   0 Batch  261/269 - Train Accuracy:  0.643, Validation Accuracy:  0.675, Loss:  0.511
# Epoch   0 Batch  262/269 - Train Accuracy:  0.685, Validation Accuracy:  0.676, Loss:  0.473
# Epoch   0 Batch  263/269 - Train Accuracy:  0.670, Validation Accuracy:  0.672, Loss:  0.491
# Epoch   0 Batch  264/269 - Train Accuracy:  0.632, Validation Accuracy:  0.656, Loss:  0.497
# Epoch   0 Batch  265/269 - Train Accuracy:  0.620, Validation Accuracy:  0.656, Loss:  0.502
# Epoch   0 Batch  266/269 - Train Accuracy:  0.658, Validation Accuracy:  0.655, Loss:  0.489
# Epoch   0 Batch  267/269 - Train Accuracy:  0.666, Validation Accuracy:  0.674, Loss:  0.495
# Epoch   1 Batch    0/269 - Train Accuracy:  0.652, Validation Accuracy:  0.673, Loss:  0.502
# Epoch   1 Batch    1/269 - Train Accuracy:  0.656, Validation Accuracy:  0.675, Loss:  0.500
# Epoch   1 Batch    2/269 - Train Accuracy:  0.652, Validation Accuracy:  0.666, Loss:  0.485
# Epoch   1 Batch    3/269 - Train Accuracy:  0.668, Validation Accuracy:  0.674, Loss:  0.499
# Epoch   1 Batch    4/269 - Train Accuracy:  0.639, Validation Accuracy:  0.673, Loss:  0.509
# Epoch   1 Batch    5/269 - Train Accuracy:  0.623, Validation Accuracy:  0.654, Loss:  0.506
# Epoch   1 Batch    6/269 - Train Accuracy:  0.650, Validation Accuracy:  0.641, Loss:  0.477
# Epoch   1 Batch    7/269 - Train Accuracy:  0.661, Validation Accuracy:  0.662, Loss:  0.464
# Epoch   1 Batch    8/269 - Train Accuracy:  0.657, Validation Accuracy:  0.684, Loss:  0.503
# Epoch   1 Batch    9/269 - Train Accuracy:  0.654, Validation Accuracy:  0.680, Loss:  0.491
# Epoch   1 Batch   10/269 - Train Accuracy:  0.671, Validation Accuracy:  0.674, Loss:  0.494
# Epoch   1 Batch   11/269 - Train Accuracy:  0.670, Validation Accuracy:  0.687, Loss:  0.478
# Epoch   1 Batch   12/269 - Train Accuracy:  0.645, Validation Accuracy:  0.679, Loss:  0.494
# Epoch   1 Batch   13/269 - Train Accuracy:  0.697, Validation Accuracy:  0.685, Loss:  0.441
# Epoch   1 Batch   14/269 - Train Accuracy:  0.668, Validation Accuracy:  0.685, Loss:  0.478
# Epoch   1 Batch   15/269 - Train Accuracy:  0.655, Validation Accuracy:  0.672, Loss:  0.462
# Epoch   1 Batch   16/269 - Train Accuracy:  0.669, Validation Accuracy:  0.664, Loss:  0.457
# Epoch   1 Batch   17/269 - Train Accuracy:  0.675, Validation Accuracy:  0.694, Loss:  0.456
# Epoch   1 Batch   18/269 - Train Accuracy:  0.670, Validation Accuracy:  0.702, Loss:  0.477
# Epoch   1 Batch   19/269 - Train Accuracy:  0.708, Validation Accuracy:  0.699, Loss:  0.419
# Epoch   1 Batch   20/269 - Train Accuracy:  0.687, Validation Accuracy:  0.704, Loss:  0.484
# Epoch   1 Batch   21/269 - Train Accuracy:  0.675, Validation Accuracy:  0.700, Loss:  0.477
# Epoch   1 Batch   22/269 - Train Accuracy:  0.694, Validation Accuracy:  0.701, Loss:  0.438
# Epoch   1 Batch   23/269 - Train Accuracy:  0.693, Validation Accuracy:  0.699, Loss:  0.431
# Epoch   1 Batch   24/269 - Train Accuracy:  0.676, Validation Accuracy:  0.696, Loss:  0.465
# Epoch   1 Batch   25/269 - Train Accuracy:  0.666, Validation Accuracy:  0.691, Loss:  0.473
# Epoch   1 Batch   26/269 - Train Accuracy:  0.701, Validation Accuracy:  0.683, Loss:  0.412
# Epoch   1 Batch   27/269 - Train Accuracy:  0.681, Validation Accuracy:  0.682, Loss:  0.431
# Epoch   1 Batch   28/269 - Train Accuracy:  0.638, Validation Accuracy:  0.679, Loss:  0.481
# Epoch   1 Batch   29/269 - Train Accuracy:  0.671, Validation Accuracy:  0.693, Loss:  0.471
# Epoch   1 Batch   30/269 - Train Accuracy:  0.692, Validation Accuracy:  0.694, Loss:  0.437
# Epoch   1 Batch   31/269 - Train Accuracy:  0.696, Validation Accuracy:  0.698, Loss:  0.426
# Epoch   1 Batch   32/269 - Train Accuracy:  0.677, Validation Accuracy:  0.680, Loss:  0.423
# Epoch   1 Batch   33/269 - Train Accuracy:  0.693, Validation Accuracy:  0.681, Loss:  0.426
# Epoch   1 Batch   34/269 - Train Accuracy:  0.684, Validation Accuracy:  0.692, Loss:  0.427
# Epoch   1 Batch   35/269 - Train Accuracy:  0.691, Validation Accuracy:  0.695, Loss:  0.451
# Epoch   1 Batch   36/269 - Train Accuracy:  0.692, Validation Accuracy:  0.691, Loss:  0.426
# Epoch   1 Batch   37/269 - Train Accuracy:  0.703, Validation Accuracy:  0.675, Loss:  0.418
# Epoch   1 Batch   38/269 - Train Accuracy:  0.690, Validation Accuracy:  0.676, Loss:  0.420
# Epoch   1 Batch   39/269 - Train Accuracy:  0.687, Validation Accuracy:  0.688, Loss:  0.426
# Epoch   1 Batch   40/269 - Train Accuracy:  0.676, Validation Accuracy:  0.706, Loss:  0.450
# Epoch   1 Batch   41/269 - Train Accuracy:  0.701, Validation Accuracy:  0.710, Loss:  0.431
# Epoch   1 Batch   42/269 - Train Accuracy:  0.710, Validation Accuracy:  0.708, Loss:  0.393
# Epoch   1 Batch   43/269 - Train Accuracy:  0.687, Validation Accuracy:  0.704, Loss:  0.433
# Epoch   1 Batch   44/269 - Train Accuracy:  0.694, Validation Accuracy:  0.698, Loss:  0.416
# Epoch   1 Batch   45/269 - Train Accuracy:  0.685, Validation Accuracy:  0.703, Loss:  0.427
# Epoch   1 Batch   46/269 - Train Accuracy:  0.694, Validation Accuracy:  0.708, Loss:  0.430
# Epoch   1 Batch   47/269 - Train Accuracy:  0.731, Validation Accuracy:  0.706, Loss:  0.388
# Epoch   1 Batch   48/269 - Train Accuracy:  0.705, Validation Accuracy:  0.713, Loss:  0.411
# Epoch   1 Batch   49/269 - Train Accuracy:  0.694, Validation Accuracy:  0.713, Loss:  0.428
# Epoch   1 Batch   50/269 - Train Accuracy:  0.675, Validation Accuracy:  0.698, Loss:  0.427
# Epoch   1 Batch   51/269 - Train Accuracy:  0.678, Validation Accuracy:  0.683, Loss:  0.406
# Epoch   1 Batch   52/269 - Train Accuracy:  0.666, Validation Accuracy:  0.690, Loss:  0.400
# Epoch   1 Batch   53/269 - Train Accuracy:  0.685, Validation Accuracy:  0.702, Loss:  0.430
# Epoch   1 Batch   54/269 - Train Accuracy:  0.712, Validation Accuracy:  0.715, Loss:  0.412
# Epoch   1 Batch   55/269 - Train Accuracy:  0.707, Validation Accuracy:  0.713, Loss:  0.406
# Epoch   1 Batch   56/269 - Train Accuracy:  0.715, Validation Accuracy:  0.722, Loss:  0.398
# Epoch   1 Batch   57/269 - Train Accuracy:  0.701, Validation Accuracy:  0.717, Loss:  0.414
# Epoch   1 Batch   58/269 - Train Accuracy:  0.706, Validation Accuracy:  0.698, Loss:  0.391
# Epoch   1 Batch   59/269 - Train Accuracy:  0.705, Validation Accuracy:  0.695, Loss:  0.378
# Epoch   1 Batch   60/269 - Train Accuracy:  0.698, Validation Accuracy:  0.705, Loss:  0.396
# Epoch   1 Batch   61/269 - Train Accuracy:  0.722, Validation Accuracy:  0.715, Loss:  0.369
# Epoch   1 Batch   62/269 - Train Accuracy:  0.713, Validation Accuracy:  0.718, Loss:  0.378
# Epoch   1 Batch   63/269 - Train Accuracy:  0.715, Validation Accuracy:  0.721, Loss:  0.396
# Epoch   1 Batch   64/269 - Train Accuracy:  0.685, Validation Accuracy:  0.706, Loss:  0.389
# Epoch   1 Batch   65/269 - Train Accuracy:  0.681, Validation Accuracy:  0.703, Loss:  0.384
# Epoch   1 Batch   66/269 - Train Accuracy:  0.701, Validation Accuracy:  0.711, Loss:  0.382
# Epoch   1 Batch   67/269 - Train Accuracy:  0.687, Validation Accuracy:  0.715, Loss:  0.395
# Epoch   1 Batch   68/269 - Train Accuracy:  0.688, Validation Accuracy:  0.721, Loss:  0.389
# Epoch   1 Batch   69/269 - Train Accuracy:  0.687, Validation Accuracy:  0.724, Loss:  0.422
# Epoch   1 Batch   70/269 - Train Accuracy:  0.729, Validation Accuracy:  0.725, Loss:  0.380
# Epoch   1 Batch   71/269 - Train Accuracy:  0.712, Validation Accuracy:  0.726, Loss:  0.410
# Epoch   1 Batch   72/269 - Train Accuracy:  0.710, Validation Accuracy:  0.726, Loss:  0.376
# Epoch   1 Batch   73/269 - Train Accuracy:  0.703, Validation Accuracy:  0.707, Loss:  0.375
# Epoch   1 Batch   74/269 - Train Accuracy:  0.686, Validation Accuracy:  0.690, Loss:  0.384
# Epoch   1 Batch   75/269 - Train Accuracy:  0.693, Validation Accuracy:  0.698, Loss:  0.383
# Epoch   1 Batch   76/269 - Train Accuracy:  0.686, Validation Accuracy:  0.702, Loss:  0.385
# Epoch   1 Batch   77/269 - Train Accuracy:  0.703, Validation Accuracy:  0.701, Loss:  0.391
# Epoch   1 Batch   78/269 - Train Accuracy:  0.691, Validation Accuracy:  0.699, Loss:  0.405
# Epoch   1 Batch   79/269 - Train Accuracy:  0.695, Validation Accuracy:  0.711, Loss:  0.453
# Epoch   1 Batch   80/269 - Train Accuracy:  0.710, Validation Accuracy:  0.719, Loss:  0.410
# Epoch   1 Batch   81/269 - Train Accuracy:  0.707, Validation Accuracy:  0.717, Loss:  0.414
# Epoch   1 Batch   82/269 - Train Accuracy:  0.707, Validation Accuracy:  0.696, Loss:  0.406
# Epoch   1 Batch   83/269 - Train Accuracy:  0.675, Validation Accuracy:  0.677, Loss:  0.421
# Epoch   1 Batch   84/269 - Train Accuracy:  0.689, Validation Accuracy:  0.691, Loss:  0.407
# Epoch   1 Batch   85/269 - Train Accuracy:  0.699, Validation Accuracy:  0.709, Loss:  0.408
# Epoch   1 Batch   86/269 - Train Accuracy:  0.683, Validation Accuracy:  0.709, Loss:  0.382
# Epoch   1 Batch   87/269 - Train Accuracy:  0.685, Validation Accuracy:  0.704, Loss:  0.421
# Epoch   1 Batch   88/269 - Train Accuracy:  0.709, Validation Accuracy:  0.703, Loss:  0.381
# Epoch   1 Batch   89/269 - Train Accuracy:  0.703, Validation Accuracy:  0.700, Loss:  0.385
# Epoch   1 Batch   90/269 - Train Accuracy:  0.687, Validation Accuracy:  0.706, Loss:  0.415
# Epoch   1 Batch   91/269 - Train Accuracy:  0.705, Validation Accuracy:  0.712, Loss:  0.375
# Epoch   1 Batch   92/269 - Train Accuracy:  0.705, Validation Accuracy:  0.727, Loss:  0.379
# Epoch   1 Batch   93/269 - Train Accuracy:  0.725, Validation Accuracy:  0.733, Loss:  0.363
# Epoch   1 Batch   94/269 - Train Accuracy:  0.722, Validation Accuracy:  0.731, Loss:  0.383
# Epoch   1 Batch   95/269 - Train Accuracy:  0.706, Validation Accuracy:  0.729, Loss:  0.380
# Epoch   1 Batch   96/269 - Train Accuracy:  0.710, Validation Accuracy:  0.725, Loss:  0.386
# Epoch   1 Batch   97/269 - Train Accuracy:  0.717, Validation Accuracy:  0.725, Loss:  0.375
# Epoch   1 Batch   98/269 - Train Accuracy:  0.710, Validation Accuracy:  0.728, Loss:  0.372
# Epoch   1 Batch   99/269 - Train Accuracy:  0.711, Validation Accuracy:  0.728, Loss:  0.376
# Epoch   1 Batch  100/269 - Train Accuracy:  0.744, Validation Accuracy:  0.734, Loss:  0.361
# Epoch   1 Batch  101/269 - Train Accuracy:  0.695, Validation Accuracy:  0.736, Loss:  0.387
# Epoch   1 Batch  102/269 - Train Accuracy:  0.712, Validation Accuracy:  0.734, Loss:  0.360
# Epoch   1 Batch  103/269 - Train Accuracy:  0.706, Validation Accuracy:  0.720, Loss:  0.359
# Epoch   1 Batch  104/269 - Train Accuracy:  0.694, Validation Accuracy:  0.705, Loss:  0.365
# Epoch   1 Batch  105/269 - Train Accuracy:  0.700, Validation Accuracy:  0.711, Loss:  0.366
# Epoch   1 Batch  106/269 - Train Accuracy:  0.711, Validation Accuracy:  0.721, Loss:  0.350
# Epoch   1 Batch  107/269 - Train Accuracy:  0.699, Validation Accuracy:  0.730, Loss:  0.381
# Epoch   1 Batch  108/269 - Train Accuracy:  0.720, Validation Accuracy:  0.734, Loss:  0.354
# Epoch   1 Batch  109/269 - Train Accuracy:  0.696, Validation Accuracy:  0.732, Loss:  0.358
# Epoch   1 Batch  110/269 - Train Accuracy:  0.715, Validation Accuracy:  0.715, Loss:  0.338
# Epoch   1 Batch  111/269 - Train Accuracy:  0.689, Validation Accuracy:  0.710, Loss:  0.363
# Epoch   1 Batch  112/269 - Train Accuracy:  0.721, Validation Accuracy:  0.718, Loss:  0.355
# Epoch   1 Batch  113/269 - Train Accuracy:  0.729, Validation Accuracy:  0.732, Loss:  0.332
# Epoch   1 Batch  114/269 - Train Accuracy:  0.730, Validation Accuracy:  0.740, Loss:  0.339
# Epoch   1 Batch  115/269 - Train Accuracy:  0.715, Validation Accuracy:  0.744, Loss:  0.363
# Epoch   1 Batch  116/269 - Train Accuracy:  0.743, Validation Accuracy:  0.746, Loss:  0.337
# Epoch   1 Batch  117/269 - Train Accuracy:  0.716, Validation Accuracy:  0.744, Loss:  0.338
# Epoch   1 Batch  118/269 - Train Accuracy:  0.757, Validation Accuracy:  0.743, Loss:  0.330
# Epoch   1 Batch  119/269 - Train Accuracy:  0.730, Validation Accuracy:  0.740, Loss:  0.334
# Epoch   1 Batch  120/269 - Train Accuracy:  0.730, Validation Accuracy:  0.741, Loss:  0.348
# Epoch   1 Batch  121/269 - Train Accuracy:  0.729, Validation Accuracy:  0.740, Loss:  0.334
# Epoch   1 Batch  122/269 - Train Accuracy:  0.736, Validation Accuracy:  0.741, Loss:  0.326
# Epoch   1 Batch  123/269 - Train Accuracy:  0.722, Validation Accuracy:  0.743, Loss:  0.341
# Epoch   1 Batch  124/269 - Train Accuracy:  0.722, Validation Accuracy:  0.733, Loss:  0.331
# Epoch   1 Batch  125/269 - Train Accuracy:  0.723, Validation Accuracy:  0.733, Loss:  0.336
# Epoch   1 Batch  126/269 - Train Accuracy:  0.734, Validation Accuracy:  0.743, Loss:  0.329
# Epoch   1 Batch  127/269 - Train Accuracy:  0.717, Validation Accuracy:  0.738, Loss:  0.330
# Epoch   1 Batch  128/269 - Train Accuracy:  0.741, Validation Accuracy:  0.736, Loss:  0.325
# Epoch   1 Batch  129/269 - Train Accuracy:  0.742, Validation Accuracy:  0.749, Loss:  0.321
# Epoch   1 Batch  130/269 - Train Accuracy:  0.725, Validation Accuracy:  0.746, Loss:  0.324
# Epoch   1 Batch  131/269 - Train Accuracy:  0.705, Validation Accuracy:  0.744, Loss:  0.334
# Epoch   1 Batch  132/269 - Train Accuracy:  0.726, Validation Accuracy:  0.744, Loss:  0.345
# Epoch   1 Batch  133/269 - Train Accuracy:  0.747, Validation Accuracy:  0.746, Loss:  0.311
# Epoch   1 Batch  134/269 - Train Accuracy:  0.727, Validation Accuracy:  0.742, Loss:  0.334
# Epoch   1 Batch  135/269 - Train Accuracy:  0.713, Validation Accuracy:  0.733, Loss:  0.340
# Epoch   1 Batch  136/269 - Train Accuracy:  0.719, Validation Accuracy:  0.738, Loss:  0.341
# Epoch   1 Batch  137/269 - Train Accuracy:  0.729, Validation Accuracy:  0.746, Loss:  0.338
# Epoch   1 Batch  138/269 - Train Accuracy:  0.739, Validation Accuracy:  0.745, Loss:  0.337
# Epoch   1 Batch  139/269 - Train Accuracy:  0.750, Validation Accuracy:  0.746, Loss:  0.307
# Epoch   1 Batch  140/269 - Train Accuracy:  0.740, Validation Accuracy:  0.747, Loss:  0.327
# Epoch   1 Batch  141/269 - Train Accuracy:  0.732, Validation Accuracy:  0.744, Loss:  0.327
# Epoch   1 Batch  142/269 - Train Accuracy:  0.744, Validation Accuracy:  0.737, Loss:  0.297
# Epoch   1 Batch  143/269 - Train Accuracy:  0.745, Validation Accuracy:  0.737, Loss:  0.303
# Epoch   1 Batch  144/269 - Train Accuracy:  0.755, Validation Accuracy:  0.750, Loss:  0.294
# Epoch   1 Batch  145/269 - Train Accuracy:  0.742, Validation Accuracy:  0.752, Loss:  0.303
# Epoch   1 Batch  146/269 - Train Accuracy:  0.739, Validation Accuracy:  0.749, Loss:  0.310
# Epoch   1 Batch  147/269 - Train Accuracy:  0.751, Validation Accuracy:  0.749, Loss:  0.306
# Epoch   1 Batch  148/269 - Train Accuracy:  0.747, Validation Accuracy:  0.743, Loss:  0.305
# Epoch   1 Batch  149/269 - Train Accuracy:  0.732, Validation Accuracy:  0.743, Loss:  0.310
# Epoch   1 Batch  150/269 - Train Accuracy:  0.749, Validation Accuracy:  0.745, Loss:  0.310
# Epoch   1 Batch  151/269 - Train Accuracy:  0.770, Validation Accuracy:  0.745, Loss:  0.286
# Epoch   1 Batch  152/269 - Train Accuracy:  0.742, Validation Accuracy:  0.755, Loss:  0.311
# Epoch   1 Batch  153/269 - Train Accuracy:  0.758, Validation Accuracy:  0.753, Loss:  0.295
# Epoch   1 Batch  154/269 - Train Accuracy:  0.738, Validation Accuracy:  0.759, Loss:  0.315
# Epoch   1 Batch  155/269 - Train Accuracy:  0.761, Validation Accuracy:  0.755, Loss:  0.288
# Epoch   1 Batch  156/269 - Train Accuracy:  0.736, Validation Accuracy:  0.752, Loss:  0.313
# Epoch   1 Batch  157/269 - Train Accuracy:  0.741, Validation Accuracy:  0.754, Loss:  0.305
# Epoch   1 Batch  158/269 - Train Accuracy:  0.738, Validation Accuracy:  0.755, Loss:  0.299
# Epoch   1 Batch  159/269 - Train Accuracy:  0.756, Validation Accuracy:  0.763, Loss:  0.297
# Epoch   1 Batch  160/269 - Train Accuracy:  0.762, Validation Accuracy:  0.768, Loss:  0.279
# Epoch   1 Batch  161/269 - Train Accuracy:  0.745, Validation Accuracy:  0.773, Loss:  0.288
# Epoch   1 Batch  162/269 - Train Accuracy:  0.759, Validation Accuracy:  0.767, Loss:  0.298
# Epoch   1 Batch  163/269 - Train Accuracy:  0.767, Validation Accuracy:  0.767, Loss:  0.298
# Epoch   1 Batch  164/269 - Train Accuracy:  0.758, Validation Accuracy:  0.766, Loss:  0.288
# Epoch   1 Batch  165/269 - Train Accuracy:  0.733, Validation Accuracy:  0.758, Loss:  0.301
# Epoch   1 Batch  166/269 - Train Accuracy:  0.747, Validation Accuracy:  0.756, Loss:  0.272
# Epoch   1 Batch  167/269 - Train Accuracy:  0.753, Validation Accuracy:  0.762, Loss:  0.283
# Epoch   1 Batch  168/269 - Train Accuracy:  0.751, Validation Accuracy:  0.764, Loss:  0.283
# Epoch   1 Batch  169/269 - Train Accuracy:  0.751, Validation Accuracy:  0.762, Loss:  0.287
# Epoch   1 Batch  170/269 - Train Accuracy:  0.752, Validation Accuracy:  0.750, Loss:  0.277
# Epoch   1 Batch  171/269 - Train Accuracy:  0.724, Validation Accuracy:  0.744, Loss:  0.295
# Epoch   1 Batch  172/269 - Train Accuracy:  0.737, Validation Accuracy:  0.755, Loss:  0.290
# Epoch   1 Batch  173/269 - Train Accuracy:  0.757, Validation Accuracy:  0.762, Loss:  0.274
# Epoch   1 Batch  174/269 - Train Accuracy:  0.762, Validation Accuracy:  0.762, Loss:  0.276
# Epoch   1 Batch  175/269 - Train Accuracy:  0.753, Validation Accuracy:  0.764, Loss:  0.294
# Epoch   1 Batch  176/269 - Train Accuracy:  0.735, Validation Accuracy:  0.766, Loss:  0.285
# Epoch   1 Batch  177/269 - Train Accuracy:  0.753, Validation Accuracy:  0.761, Loss:  0.261
# Epoch   1 Batch  178/269 - Train Accuracy:  0.753, Validation Accuracy:  0.765, Loss:  0.280
# Epoch   1 Batch  179/269 - Train Accuracy:  0.757, Validation Accuracy:  0.767, Loss:  0.278
# Epoch   1 Batch  180/269 - Train Accuracy:  0.757, Validation Accuracy:  0.767, Loss:  0.274
# Epoch   1 Batch  181/269 - Train Accuracy:  0.750, Validation Accuracy:  0.772, Loss:  0.277
# Epoch   1 Batch  182/269 - Train Accuracy:  0.763, Validation Accuracy:  0.774, Loss:  0.273
# Epoch   1 Batch  183/269 - Train Accuracy:  0.791, Validation Accuracy:  0.771, Loss:  0.244
# Epoch   1 Batch  184/269 - Train Accuracy:  0.738, Validation Accuracy:  0.763, Loss:  0.288
# Epoch   1 Batch  185/269 - Train Accuracy:  0.768, Validation Accuracy:  0.772, Loss:  0.266
# Epoch   1 Batch  186/269 - Train Accuracy:  0.751, Validation Accuracy:  0.769, Loss:  0.275
# Epoch   1 Batch  187/269 - Train Accuracy:  0.752, Validation Accuracy:  0.765, Loss:  0.267
# Epoch   1 Batch  188/269 - Train Accuracy:  0.782, Validation Accuracy:  0.769, Loss:  0.261
# Epoch   1 Batch  189/269 - Train Accuracy:  0.768, Validation Accuracy:  0.749, Loss:  0.247
# Epoch   1 Batch  190/269 - Train Accuracy:  0.737, Validation Accuracy:  0.739, Loss:  0.266
# Epoch   1 Batch  191/269 - Train Accuracy:  0.747, Validation Accuracy:  0.739, Loss:  0.257
# Epoch   1 Batch  192/269 - Train Accuracy:  0.770, Validation Accuracy:  0.762, Loss:  0.258
# Epoch   1 Batch  193/269 - Train Accuracy:  0.763, Validation Accuracy:  0.768, Loss:  0.260
# Epoch   1 Batch  194/269 - Train Accuracy:  0.783, Validation Accuracy:  0.771, Loss:  0.267
# Epoch   1 Batch  195/269 - Train Accuracy:  0.769, Validation Accuracy:  0.773, Loss:  0.254
# Epoch   1 Batch  196/269 - Train Accuracy:  0.753, Validation Accuracy:  0.772, Loss:  0.271
# Epoch   1 Batch  197/269 - Train Accuracy:  0.733, Validation Accuracy:  0.752, Loss:  0.277
# Epoch   1 Batch  198/269 - Train Accuracy:  0.734, Validation Accuracy:  0.746, Loss:  0.275
# Epoch   1 Batch  199/269 - Train Accuracy:  0.748, Validation Accuracy:  0.749, Loss:  0.258
# Epoch   1 Batch  200/269 - Train Accuracy:  0.769, Validation Accuracy:  0.777, Loss:  0.266
# Epoch   1 Batch  201/269 - Train Accuracy:  0.763, Validation Accuracy:  0.782, Loss:  0.250
# Epoch   1 Batch  202/269 - Train Accuracy:  0.765, Validation Accuracy:  0.778, Loss:  0.255
# Epoch   1 Batch  203/269 - Train Accuracy:  0.761, Validation Accuracy:  0.775, Loss:  0.270
# Epoch   1 Batch  204/269 - Train Accuracy:  0.751, Validation Accuracy:  0.761, Loss:  0.274
# Epoch   1 Batch  205/269 - Train Accuracy:  0.743, Validation Accuracy:  0.751, Loss:  0.251
# Epoch   1 Batch  206/269 - Train Accuracy:  0.752, Validation Accuracy:  0.757, Loss:  0.263
# Epoch   1 Batch  207/269 - Train Accuracy:  0.765, Validation Accuracy:  0.773, Loss:  0.254
# Epoch   1 Batch  208/269 - Train Accuracy:  0.762, Validation Accuracy:  0.777, Loss:  0.257
# Epoch   1 Batch  209/269 - Train Accuracy:  0.770, Validation Accuracy:  0.777, Loss:  0.248
# Epoch   1 Batch  210/269 - Train Accuracy:  0.770, Validation Accuracy:  0.775, Loss:  0.245
# Epoch   1 Batch  211/269 - Train Accuracy:  0.760, Validation Accuracy:  0.771, Loss:  0.262
# Epoch   1 Batch  212/269 - Train Accuracy:  0.749, Validation Accuracy:  0.763, Loss:  0.259
# Epoch   1 Batch  213/269 - Train Accuracy:  0.755, Validation Accuracy:  0.758, Loss:  0.253
# Epoch   1 Batch  214/269 - Train Accuracy:  0.779, Validation Accuracy:  0.770, Loss:  0.253
# Epoch   1 Batch  215/269 - Train Accuracy:  0.788, Validation Accuracy:  0.778, Loss:  0.232
# Epoch   1 Batch  216/269 - Train Accuracy:  0.755, Validation Accuracy:  0.778, Loss:  0.265
# Epoch   1 Batch  217/269 - Train Accuracy:  0.742, Validation Accuracy:  0.770, Loss:  0.257
# Epoch   1 Batch  218/269 - Train Accuracy:  0.763, Validation Accuracy:  0.771, Loss:  0.247
# Epoch   1 Batch  219/269 - Train Accuracy:  0.774, Validation Accuracy:  0.774, Loss:  0.258
# Epoch   1 Batch  220/269 - Train Accuracy:  0.763, Validation Accuracy:  0.777, Loss:  0.234
# Epoch   1 Batch  221/269 - Train Accuracy:  0.789, Validation Accuracy:  0.779, Loss:  0.240
# Epoch   1 Batch  222/269 - Train Accuracy:  0.782, Validation Accuracy:  0.777, Loss:  0.236
# Epoch   1 Batch  223/269 - Train Accuracy:  0.763, Validation Accuracy:  0.778, Loss:  0.244
# Epoch   1 Batch  224/269 - Train Accuracy:  0.779, Validation Accuracy:  0.781, Loss:  0.252
# Epoch   1 Batch  225/269 - Train Accuracy:  0.761, Validation Accuracy:  0.775, Loss:  0.249
# Epoch   1 Batch  226/269 - Train Accuracy:  0.758, Validation Accuracy:  0.770, Loss:  0.246
# Epoch   1 Batch  227/269 - Train Accuracy:  0.796, Validation Accuracy:  0.764, Loss:  0.214
# Epoch   1 Batch  228/269 - Train Accuracy:  0.772, Validation Accuracy:  0.770, Loss:  0.236
# Epoch   1 Batch  229/269 - Train Accuracy:  0.771, Validation Accuracy:  0.788, Loss:  0.236
# Epoch   1 Batch  230/269 - Train Accuracy:  0.764, Validation Accuracy:  0.784, Loss:  0.245
# Epoch   1 Batch  231/269 - Train Accuracy:  0.737, Validation Accuracy:  0.783, Loss:  0.255
# Epoch   1 Batch  232/269 - Train Accuracy:  0.755, Validation Accuracy:  0.786, Loss:  0.265
# Epoch   1 Batch  233/269 - Train Accuracy:  0.786, Validation Accuracy:  0.785, Loss:  0.240
# Epoch   1 Batch  234/269 - Train Accuracy:  0.789, Validation Accuracy:  0.782, Loss:  0.242
# Epoch   1 Batch  235/269 - Train Accuracy:  0.803, Validation Accuracy:  0.786, Loss:  0.220
# Epoch   1 Batch  236/269 - Train Accuracy:  0.768, Validation Accuracy:  0.787, Loss:  0.234
# Epoch   1 Batch  237/269 - Train Accuracy:  0.767, Validation Accuracy:  0.785, Loss:  0.234
# Epoch   1 Batch  238/269 - Train Accuracy:  0.784, Validation Accuracy:  0.781, Loss:  0.226
# Epoch   1 Batch  239/269 - Train Accuracy:  0.779, Validation Accuracy:  0.776, Loss:  0.233
# Epoch   1 Batch  240/269 - Train Accuracy:  0.799, Validation Accuracy:  0.772, Loss:  0.206
# Epoch   1 Batch  241/269 - Train Accuracy:  0.774, Validation Accuracy:  0.782, Loss:  0.232
# Epoch   1 Batch  242/269 - Train Accuracy:  0.763, Validation Accuracy:  0.790, Loss:  0.235
# Epoch   1 Batch  243/269 - Train Accuracy:  0.789, Validation Accuracy:  0.792, Loss:  0.220
# Epoch   1 Batch  244/269 - Train Accuracy:  0.769, Validation Accuracy:  0.792, Loss:  0.239
# Epoch   1 Batch  245/269 - Train Accuracy:  0.764, Validation Accuracy:  0.792, Loss:  0.244
# Epoch   1 Batch  246/269 - Train Accuracy:  0.754, Validation Accuracy:  0.788, Loss:  0.227
# Epoch   1 Batch  247/269 - Train Accuracy:  0.776, Validation Accuracy:  0.790, Loss:  0.231
# ...
# Epoch   4 Batch   97/269 - Train Accuracy:  0.945, Validation Accuracy:  0.942, Loss:  0.033
# Epoch   4 Batch   98/269 - Train Accuracy:  0.939, Validation Accuracy:  0.943, Loss:  0.030
# Epoch   4 Batch   99/269 - Train Accuracy:  0.947, Validation Accuracy:  0.947, Loss:  0.027
# Epoch   4 Batch  100/269 - Train Accuracy:  0.952, Validation Accuracy:  0.945, Loss:  0.029
# Epoch   4 Batch  101/269 - Train Accuracy:  0.942, Validation Accuracy:  0.950, Loss:  0.036
# Epoch   4 Batch  102/269 - Train Accuracy:  0.941, Validation Accuracy:  0.945, Loss:  0.027
# Epoch   4 Batch  103/269 - Train Accuracy:  0.953, Validation Accuracy:  0.947, Loss:  0.030
# Epoch   4 Batch  104/269 - Train Accuracy:  0.948, Validation Accuracy:  0.947, Loss:  0.027
# Epoch   4 Batch  105/269 - Train Accuracy:  0.947, Validation Accuracy:  0.951, Loss:  0.028
# Epoch   4 Batch  106/269 - Train Accuracy:  0.957, Validation Accuracy:  0.948, Loss:  0.023
# Epoch   4 Batch  107/269 - Train Accuracy:  0.953, Validation Accuracy:  0.948, Loss:  0.028
# Epoch   4 Batch  108/269 - Train Accuracy:  0.956, Validation Accuracy:  0.949, Loss:  0.025
# Epoch   4 Batch  109/269 - Train Accuracy:  0.943, Validation Accuracy:  0.950, Loss:  0.029
# Epoch   4 Batch  110/269 - Train Accuracy:  0.946, Validation Accuracy:  0.945, Loss:  0.026
# Epoch   4 Batch  111/269 - Train Accuracy:  0.950, Validation Accuracy:  0.946, Loss:  0.028
# Epoch   4 Batch  112/269 - Train Accuracy:  0.949, Validation Accuracy:  0.948, Loss:  0.028
# Epoch   4 Batch  113/269 - Train Accuracy:  0.957, Validation Accuracy:  0.950, Loss:  0.025
# Epoch   4 Batch  114/269 - Train Accuracy:  0.952, Validation Accuracy:  0.950, Loss:  0.027
# Epoch   4 Batch  115/269 - Train Accuracy:  0.953, Validation Accuracy:  0.947, Loss:  0.024
# Epoch   4 Batch  116/269 - Train Accuracy:  0.961, Validation Accuracy:  0.947, Loss:  0.024
# Epoch   4 Batch  117/269 - Train Accuracy:  0.960, Validation Accuracy:  0.952, Loss:  0.024
# Epoch   4 Batch  118/269 - Train Accuracy:  0.951, Validation Accuracy:  0.949, Loss:  0.023
# Epoch   4 Batch  119/269 - Train Accuracy:  0.950, Validation Accuracy:  0.948, Loss:  0.027
# Epoch   4 Batch  120/269 - Train Accuracy:  0.949, Validation Accuracy:  0.948, Loss:  0.025
# Epoch   4 Batch  121/269 - Train Accuracy:  0.960, Validation Accuracy:  0.947, Loss:  0.022
# Epoch   4 Batch  122/269 - Train Accuracy:  0.947, Validation Accuracy:  0.948, Loss:  0.025
# Epoch   4 Batch  123/269 - Train Accuracy:  0.939, Validation Accuracy:  0.946, Loss:  0.025
# Epoch   4 Batch  124/269 - Train Accuracy:  0.956, Validation Accuracy:  0.945, Loss:  0.026
# Epoch   4 Batch  125/269 - Train Accuracy:  0.953, Validation Accuracy:  0.943, Loss:  0.026
# Epoch   4 Batch  126/269 - Train Accuracy:  0.941, Validation Accuracy:  0.945, Loss:  0.028
# Epoch   4 Batch  127/269 - Train Accuracy:  0.955, Validation Accuracy:  0.945, Loss:  0.027
# Epoch   4 Batch  128/269 - Train Accuracy:  0.949, Validation Accuracy:  0.943, Loss:  0.024
# Epoch   4 Batch  129/269 - Train Accuracy:  0.949, Validation Accuracy:  0.948, Loss:  0.029
# Epoch   4 Batch  130/269 - Train Accuracy:  0.948, Validation Accuracy:  0.952, Loss:  0.028
# Epoch   4 Batch  131/269 - Train Accuracy:  0.944, Validation Accuracy:  0.955, Loss:  0.027
# Epoch   4 Batch  132/269 - Train Accuracy:  0.940, Validation Accuracy:  0.950, Loss:  0.031
# Epoch   4 Batch  133/269 - Train Accuracy:  0.951, Validation Accuracy:  0.948, Loss:  0.022
# Epoch   4 Batch  134/269 - Train Accuracy:  0.952, Validation Accuracy:  0.951, Loss:  0.028
# Epoch   4 Batch  135/269 - Train Accuracy:  0.944, Validation Accuracy:  0.948, Loss:  0.025
# Epoch   4 Batch  136/269 - Train Accuracy:  0.941, Validation Accuracy:  0.949, Loss:  0.027
# Epoch   4 Batch  137/269 - Train Accuracy:  0.949, Validation Accuracy:  0.947, Loss:  0.032
# Epoch   4 Batch  138/269 - Train Accuracy:  0.957, Validation Accuracy:  0.946, Loss:  0.022
# Epoch   4 Batch  139/269 - Train Accuracy:  0.957, Validation Accuracy:  0.945, Loss:  0.023
# Epoch   4 Batch  140/269 - Train Accuracy:  0.948, Validation Accuracy:  0.944, Loss:  0.029
# Epoch   4 Batch  141/269 - Train Accuracy:  0.952, Validation Accuracy:  0.943, Loss:  0.027
# Epoch   4 Batch  142/269 - Train Accuracy:  0.940, Validation Accuracy:  0.944, Loss:  0.027
# Epoch   4 Batch  143/269 - Train Accuracy:  0.951, Validation Accuracy:  0.946, Loss:  0.022
# Epoch   4 Batch  144/269 - Train Accuracy:  0.962, Validation Accuracy:  0.952, Loss:  0.020
# Epoch   4 Batch  145/269 - Train Accuracy:  0.965, Validation Accuracy:  0.954, Loss:  0.020
# Epoch   4 Batch  146/269 - Train Accuracy:  0.954, Validation Accuracy:  0.952, Loss:  0.024
# Epoch   4 Batch  147/269 - Train Accuracy:  0.947, Validation Accuracy:  0.951, Loss:  0.031
# Epoch   4 Batch  148/269 - Train Accuracy:  0.957, Validation Accuracy:  0.953, Loss:  0.023
# Epoch   4 Batch  149/269 - Train Accuracy:  0.948, Validation Accuracy:  0.956, Loss:  0.031
# Epoch   4 Batch  150/269 - Train Accuracy:  0.947, Validation Accuracy:  0.956, Loss:  0.029
# Epoch   4 Batch  151/269 - Train Accuracy:  0.956, Validation Accuracy:  0.954, Loss:  0.027
# Epoch   4 Batch  152/269 - Train Accuracy:  0.949, Validation Accuracy:  0.949, Loss:  0.025
# Epoch   4 Batch  153/269 - Train Accuracy:  0.957, Validation Accuracy:  0.946, Loss:  0.022
# Epoch   4 Batch  154/269 - Train Accuracy:  0.947, Validation Accuracy:  0.945, Loss:  0.027
# Epoch   4 Batch  155/269 - Train Accuracy:  0.957, Validation Accuracy:  0.946, Loss:  0.027
# Epoch   4 Batch  156/269 - Train Accuracy:  0.955, Validation Accuracy:  0.953, Loss:  0.025
# Epoch   4 Batch  157/269 - Train Accuracy:  0.950, Validation Accuracy:  0.957, Loss:  0.023
# Epoch   4 Batch  158/269 - Train Accuracy:  0.954, Validation Accuracy:  0.954, Loss:  0.025
# Epoch   4 Batch  159/269 - Train Accuracy:  0.952, Validation Accuracy:  0.954, Loss:  0.025
# Epoch   4 Batch  160/269 - Train Accuracy:  0.951, Validation Accuracy:  0.952, Loss:  0.025
# Epoch   4 Batch  161/269 - Train Accuracy:  0.952, Validation Accuracy:  0.953, Loss:  0.021
# Epoch   4 Batch  162/269 - Train Accuracy:  0.961, Validation Accuracy:  0.956, Loss:  0.029
# Epoch   4 Batch  163/269 - Train Accuracy:  0.958, Validation Accuracy:  0.956, Loss:  0.026
# Epoch   4 Batch  164/269 - Train Accuracy:  0.963, Validation Accuracy:  0.956, Loss:  0.023
# Epoch   4 Batch  165/269 - Train Accuracy:  0.954, Validation Accuracy:  0.957, Loss:  0.025
# Epoch   4 Batch  166/269 - Train Accuracy:  0.962, Validation Accuracy:  0.958, Loss:  0.020
# Epoch   4 Batch  167/269 - Train Accuracy:  0.955, Validation Accuracy:  0.959, Loss:  0.026
# Epoch   4 Batch  168/269 - Train Accuracy:  0.947, Validation Accuracy:  0.960, Loss:  0.027
# Epoch   4 Batch  169/269 - Train Accuracy:  0.943, Validation Accuracy:  0.960, Loss:  0.024
# Epoch   4 Batch  170/269 - Train Accuracy:  0.953, Validation Accuracy:  0.959, Loss:  0.023
# Epoch   4 Batch  171/269 - Train Accuracy:  0.951, Validation Accuracy:  0.955, Loss:  0.027
# Epoch   4 Batch  172/269 - Train Accuracy:  0.950, Validation Accuracy:  0.953, Loss:  0.027
# Epoch   4 Batch  173/269 - Train Accuracy:  0.952, Validation Accuracy:  0.955, Loss:  0.024
# Epoch   4 Batch  174/269 - Train Accuracy:  0.954, Validation Accuracy:  0.957, Loss:  0.023
# Epoch   4 Batch  175/269 - Train Accuracy:  0.949, Validation Accuracy:  0.953, Loss:  0.033
# Epoch   4 Batch  176/269 - Train Accuracy:  0.950, Validation Accuracy:  0.953, Loss:  0.024
# Epoch   4 Batch  177/269 - Train Accuracy:  0.962, Validation Accuracy:  0.952, Loss:  0.024
# Epoch   4 Batch  178/269 - Train Accuracy:  0.962, Validation Accuracy:  0.951, Loss:  0.022
# Epoch   4 Batch  179/269 - Train Accuracy:  0.958, Validation Accuracy:  0.952, Loss:  0.024
# Epoch   4 Batch  180/269 - Train Accuracy:  0.961, Validation Accuracy:  0.953, Loss:  0.024
# Epoch   4 Batch  181/269 - Train Accuracy:  0.945, Validation Accuracy:  0.954, Loss:  0.029
# Epoch   4 Batch  182/269 - Train Accuracy:  0.949, Validation Accuracy:  0.954, Loss:  0.023
# Epoch   4 Batch  183/269 - Train Accuracy:  0.962, Validation Accuracy:  0.954, Loss:  0.019
# Epoch   4 Batch  184/269 - Train Accuracy:  0.954, Validation Accuracy:  0.947, Loss:  0.022
# Epoch   4 Batch  185/269 - Train Accuracy:  0.967, Validation Accuracy:  0.947, Loss:  0.025
# Epoch   4 Batch  186/269 - Train Accuracy:  0.955, Validation Accuracy:  0.948, Loss:  0.018
# Epoch   4 Batch  187/269 - Train Accuracy:  0.952, Validation Accuracy:  0.943, Loss:  0.024
# Epoch   4 Batch  188/269 - Train Accuracy:  0.955, Validation Accuracy:  0.937, Loss:  0.021
# Epoch   4 Batch  189/269 - Train Accuracy:  0.959, Validation Accuracy:  0.939, Loss:  0.024
# Epoch   4 Batch  190/269 - Train Accuracy:  0.951, Validation Accuracy:  0.939, Loss:  0.025
# Epoch   4 Batch  191/269 - Train Accuracy:  0.958, Validation Accuracy:  0.946, Loss:  0.023
# Epoch   4 Batch  192/269 - Train Accuracy:  0.955, Validation Accuracy:  0.947, Loss:  0.020
# Epoch   4 Batch  193/269 - Train Accuracy:  0.961, Validation Accuracy:  0.948, Loss:  0.021
# Epoch   4 Batch  194/269 - Train Accuracy:  0.948, Validation Accuracy:  0.946, Loss:  0.022
# Epoch   4 Batch  195/269 - Train Accuracy:  0.961, Validation Accuracy:  0.945, Loss:  0.020
# Epoch   4 Batch  196/269 - Train Accuracy:  0.951, Validation Accuracy:  0.946, Loss:  0.026
# Epoch   4 Batch  197/269 - Train Accuracy:  0.956, Validation Accuracy:  0.949, Loss:  0.023
# Epoch   4 Batch  198/269 - Train Accuracy:  0.960, Validation Accuracy:  0.955, Loss:  0.023
# Epoch   4 Batch  199/269 - Train Accuracy:  0.955, Validation Accuracy:  0.953, Loss:  0.025
# Epoch   4 Batch  200/269 - Train Accuracy:  0.969, Validation Accuracy:  0.947, Loss:  0.021
# Epoch   4 Batch  201/269 - Train Accuracy:  0.953, Validation Accuracy:  0.943, Loss:  0.022
# Epoch   4 Batch  202/269 - Train Accuracy:  0.950, Validation Accuracy:  0.943, Loss:  0.024
# Epoch   4 Batch  203/269 - Train Accuracy:  0.957, Validation Accuracy:  0.948, Loss:  0.025
# Epoch   4 Batch  204/269 - Train Accuracy:  0.959, Validation Accuracy:  0.948, Loss:  0.022
# Epoch   4 Batch  205/269 - Train Accuracy:  0.961, Validation Accuracy:  0.950, Loss:  0.022
# Epoch   4 Batch  206/269 - Train Accuracy:  0.945, Validation Accuracy:  0.952, Loss:  0.031
# Epoch   4 Batch  207/269 - Train Accuracy:  0.957, Validation Accuracy:  0.952, Loss:  0.029
# Epoch   4 Batch  208/269 - Train Accuracy:  0.956, Validation Accuracy:  0.949, Loss:  0.023
# Epoch   4 Batch  209/269 - Train Accuracy:  0.958, Validation Accuracy:  0.951, Loss:  0.028
# Epoch   4 Batch  210/269 - Train Accuracy:  0.949, Validation Accuracy:  0.950, Loss:  0.027
# Epoch   4 Batch  211/269 - Train Accuracy:  0.953, Validation Accuracy:  0.952, Loss:  0.028
# Epoch   4 Batch  212/269 - Train Accuracy:  0.954, Validation Accuracy:  0.951, Loss:  0.029
# Epoch   4 Batch  213/269 - Train Accuracy:  0.949, Validation Accuracy:  0.949, Loss:  0.023
# Epoch   4 Batch  214/269 - Train Accuracy:  0.962, Validation Accuracy:  0.942, Loss:  0.025
# Epoch   4 Batch  215/269 - Train Accuracy:  0.946, Validation Accuracy:  0.938, Loss:  0.026
# Epoch   4 Batch  216/269 - Train Accuracy:  0.942, Validation Accuracy:  0.939, Loss:  0.034
# Epoch   4 Batch  217/269 - Train Accuracy:  0.953, Validation Accuracy:  0.949, Loss:  0.029
# Epoch   4 Batch  218/269 - Train Accuracy:  0.961, Validation Accuracy:  0.946, Loss:  0.023
# Epoch   4 Batch  219/269 - Train Accuracy:  0.951, Validation Accuracy:  0.946, Loss:  0.023
# Epoch   4 Batch  220/269 - Train Accuracy:  0.953, Validation Accuracy:  0.947, Loss:  0.024
# Epoch   4 Batch  221/269 - Train Accuracy:  0.950, Validation Accuracy:  0.948, Loss:  0.027
# Epoch   4 Batch  222/269 - Train Accuracy:  0.966, Validation Accuracy:  0.949, Loss:  0.021
# Epoch   4 Batch  223/269 - Train Accuracy:  0.946, Validation Accuracy:  0.955, Loss:  0.024
# Epoch   4 Batch  224/269 - Train Accuracy:  0.955, Validation Accuracy:  0.950, Loss:  0.029
# Epoch   4 Batch  225/269 - Train Accuracy:  0.950, Validation Accuracy:  0.948, Loss:  0.026
# Epoch   4 Batch  226/269 - Train Accuracy:  0.946, Validation Accuracy:  0.948, Loss:  0.028
# Epoch   4 Batch  227/269 - Train Accuracy:  0.952, Validation Accuracy:  0.950, Loss:  0.032
# Epoch   4 Batch  228/269 - Train Accuracy:  0.954, Validation Accuracy:  0.954, Loss:  0.023
# Epoch   4 Batch  229/269 - Train Accuracy:  0.954, Validation Accuracy:  0.956, Loss:  0.024
# Epoch   4 Batch  230/269 - Train Accuracy:  0.958, Validation Accuracy:  0.956, Loss:  0.021
# Epoch   4 Batch  231/269 - Train Accuracy:  0.957, Validation Accuracy:  0.956, Loss:  0.024
# Epoch   4 Batch  232/269 - Train Accuracy:  0.960, Validation Accuracy:  0.952, Loss:  0.022
# Epoch   4 Batch  233/269 - Train Accuracy:  0.962, Validation Accuracy:  0.953, Loss:  0.027
# Epoch   4 Batch  234/269 - Train Accuracy:  0.958, Validation Accuracy:  0.953, Loss:  0.022
# Epoch   4 Batch  235/269 - Train Accuracy:  0.969, Validation Accuracy:  0.954, Loss:  0.018
# Epoch   4 Batch  236/269 - Train Accuracy:  0.953, Validation Accuracy:  0.955, Loss:  0.023
# Epoch   4 Batch  237/269 - Train Accuracy:  0.960, Validation Accuracy:  0.955, Loss:  0.022
# Epoch   4 Batch  238/269 - Train Accuracy:  0.957, Validation Accuracy:  0.959, Loss:  0.024
# Epoch   4 Batch  239/269 - Train Accuracy:  0.960, Validation Accuracy:  0.956, Loss:  0.022
# Epoch   4 Batch  240/269 - Train Accuracy:  0.960, Validation Accuracy:  0.955, Loss:  0.019
# Epoch   4 Batch  241/269 - Train Accuracy:  0.952, Validation Accuracy:  0.957, Loss:  0.026
# Epoch   4 Batch  242/269 - Train Accuracy:  0.959, Validation Accuracy:  0.954, Loss:  0.018
# Epoch   4 Batch  243/269 - Train Accuracy:  0.966, Validation Accuracy:  0.952, Loss:  0.019
# Epoch   4 Batch  244/269 - Train Accuracy:  0.947, Validation Accuracy:  0.951, Loss:  0.022
# Epoch   4 Batch  245/269 - Train Accuracy:  0.951, Validation Accuracy:  0.952, Loss:  0.022
# Epoch   4 Batch  246/269 - Train Accuracy:  0.956, Validation Accuracy:  0.950, Loss:  0.022
# Epoch   4 Batch  247/269 - Train Accuracy:  0.952, Validation Accuracy:  0.947, Loss:  0.022
# Epoch   4 Batch  248/269 - Train Accuracy:  0.957, Validation Accuracy:  0.947, Loss:  0.020
# Epoch   4 Batch  249/269 - Train Accuracy:  0.958, Validation Accuracy:  0.952, Loss:  0.019
# Epoch   4 Batch  250/269 - Train Accuracy:  0.953, Validation Accuracy:  0.948, Loss:  0.022
# Epoch   4 Batch  251/269 - Train Accuracy:  0.964, Validation Accuracy:  0.950, Loss:  0.020
# Epoch   4 Batch  252/269 - Train Accuracy:  0.954, Validation Accuracy:  0.950, Loss:  0.018
# Epoch   4 Batch  253/269 - Train Accuracy:  0.949, Validation Accuracy:  0.954, Loss:  0.024
# Epoch   4 Batch  254/269 - Train Accuracy:  0.958, Validation Accuracy:  0.952, Loss:  0.020
# Epoch   4 Batch  255/269 - Train Accuracy:  0.959, Validation Accuracy:  0.952, Loss:  0.023
# Epoch   4 Batch  256/269 - Train Accuracy:  0.957, Validation Accuracy:  0.951, Loss:  0.023
# Epoch   4 Batch  257/269 - Train Accuracy:  0.946, Validation Accuracy:  0.951, Loss:  0.028
# Epoch   4 Batch  258/269 - Train Accuracy:  0.952, Validation Accuracy:  0.953, Loss:  0.021
# Epoch   4 Batch  259/269 - Train Accuracy:  0.954, Validation Accuracy:  0.952, Loss:  0.025
# Epoch   4 Batch  260/269 - Train Accuracy:  0.951, Validation Accuracy:  0.954, Loss:  0.023
# Epoch   4 Batch  261/269 - Train Accuracy:  0.961, Validation Accuracy:  0.956, Loss:  0.019
# Epoch   4 Batch  262/269 - Train Accuracy:  0.953, Validation Accuracy:  0.956, Loss:  0.025
# Epoch   4 Batch  263/269 - Train Accuracy:  0.963, Validation Accuracy:  0.953, Loss:  0.024
# Epoch   4 Batch  264/269 - Train Accuracy:  0.940, Validation Accuracy:  0.956, Loss:  0.026
# Epoch   4 Batch  265/269 - Train Accuracy:  0.954, Validation Accuracy:  0.959, Loss:  0.024
# Epoch   4 Batch  266/269 - Train Accuracy:  0.956, Validation Accuracy:  0.953, Loss:  0.017
# Epoch   4 Batch  267/269 - Train Accuracy:  0.960, Validation Accuracy:  0.948, Loss:  0.023
# Model Trained and Saved

# %%
plt.show()

# %% [markdown]
# ### Save Parameters
# Save the `batch_size` and `save_path` parameters for inference.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
# Save parameters for checkpoint
helper.save_params(save_path)

# %% [markdown]
# # Checkpoint

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import tensorflow as tf
import numpy as np
import helper
import problem_unittests as tests

_, (source_vocab_to_int, target_vocab_to_int), (source_int_to_vocab, target_int_to_vocab) = helper.load_preprocess()
load_path = helper.load_params()

# %% [markdown]
# ## Sentence to Sequence
# To feed a sentence into the model for translation, you first need to preprocess it.  Implement the function `sentence_to_seq()` to preprocess new sentences.
#
# - Convert the sentence to lowercase
# - Convert words into ids using `vocab_to_int`
# - Convert words not in the vocabulary, to the `<UNK>` word id.

# %%
def sentence_to_seq(sentence, vocab_to_int):
    """
    Convert a sentence to a sequence of ids
    :param sentence: String
    :param vocab_to_int: Dictionary to go from the words to an id
    :return: List of word ids
    """
    # TODO: Implement Function
    words_lower_case = [word.lower() for word in sentence.split()]
    # default to '<UNK>' in case word is non-existent in domain
    seq_word_id = [vocab_to_int.get(l_case_word, vocab_to_int['<UNK>']) for l_case_word in words_lower_case]
    
    #print(seq_word_id)
    return seq_word_id


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_sentence_to_seq(sentence_to_seq)
# Out:
# Tests Passed

# %% [markdown]
# ## Translate
# This will translate `translate_sentence` from English to French.

# %%
translate_sentence = 'he saw a old yellow truck .'


"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
translate_sentence = sentence_to_seq(translate_sentence, source_vocab_to_int)

loaded_graph = tf.Graph()
with tf.Session(graph=loaded_graph) as sess:
    # Load saved model
    loader = tf.train.import_meta_graph(load_path + '.meta')
    loader.restore(sess, load_path)

    input_data = loaded_graph.get_tensor_by_name('input:0')
    logits = loaded_graph.get_tensor_by_name('logits:0')
    keep_prob = loaded_graph.get_tensor_by_name('keep_prob:0')

    translate_logits = sess.run(logits, {input_data: [translate_sentence], keep_prob: 1.0})[0]

print('Input')
print('  Word Ids:      {}'.format([i for i in translate_sentence]))
print('  English Words: {}'.format([source_int_to_vocab[i] for i in translate_sentence]))

print('\nPrediction')
print('  Word Ids:      {}'.format([i for i in np.argmax(translate_logits, 1)]))
print('  French Words: {}'.format([target_int_to_vocab[i] for i in np.argmax(translate_logits, 1)]))
# Out:
# Input
#   Word Ids:      [68, 63, 42, 44, 135, 66, 202]
#   English Words: ['he', 'saw', 'a', 'old', 'yellow', 'truck', '.']
#
# Prediction
#   Word Ids:      [186, 89, 93, 313, 46, 54, 65, 181, 263, 1]
#   French Words: ['la', 'banane', 'est', 'jamais', 'à', 'sec', 'en', 'février', '.', '<EOS>']

# %% [markdown]
# ## Imperfect Translation
# You might notice that some sentences translate better than others.  Since the dataset you're using only has a vocabulary of 227 English words of the thousands that you use, you're only going to see good results using these words.  Additionally, the translations in this data set were made by Google translate, so the translations themselves aren't particularly good.  (We apologize to the French speakers out there!) Thankfully, for this project, you don't need a perfect translation. However, if you want to create a better translation model, you'll need better data.
#
# You can train on the [WMT10 French-English corpus](http://www.statmt.org/wmt10/training-giga-fren.tar).  This dataset has more vocabulary and richer in topics discussed.  However, this will take you days to train, so make sure you've a GPU and the neural network is performing well on dataset we provided.  Just make sure you play with the WMT10 corpus after you've submitted this project.
# ## Submitting This Project
# When submitting this project, make sure to run all the cells before saving the notebook. Save the notebook file as "dlnd_language_translation.ipynb" and save it as a HTML file under "File" -> "Download as". Include the "helper.py" and "problem_unittests.py" files in your submission.
